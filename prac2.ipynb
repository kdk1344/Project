# %%
import warnings
warnings.filterwarnings('ignore') # 경고 메시지를 무시하고 숨긴다.
from IPython.display import Image
import numpy as np
import pandas as pd
from datetime import datetime
import glob
import os
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder

# %%
cosurv = pd.read_csv('./data/corona/Covid19SidoInfState.csv')
cosurv
# Out:
#          seq             stdDay gubun gubunCn           gubunEn  deathCnt  \
# 0          1    2020년 3월 1일 16시    합계     NaN               NaN      18.0
# 1          2    2020년 3월 1일 16시    서울     NaN               NaN       NaN
# 2          3    2020년 3월 1일 16시    부산     NaN               NaN       NaN
# 3          4    2020년 3월 1일 16시    대구     NaN               NaN       9.0
# 4          5    2020년 3월 1일 16시    인천     NaN               NaN       NaN
# ...      ...                ...   ...     ...               ...       ...
# 12750  13742  2021년 12월 06일 00시    전남      全南      Jeollanam-do      27.0
# 12751  13743  2021년 12월 06일 00시    경북      庆北  Gyeongsangbuk-do     112.0
# 12752  13744  2021년 12월 06일 00시    경남      庆南  Gyeongsangnam-do      62.0
# 12753  13745  2021년 12월 06일 00시    제주      济州              Jeju       9.0
# 12754  13746  2021년 12월 06일 00시    검역     隔離區         Lazaretto      16.0
#
#        incDec  isolClearCnt qurRate   defCnt  isolIngCnt  overFlowCnt  \
# 0       586.0           NaN     NaN      NaN         NaN          NaN
# 1        10.0           NaN     NaN      NaN         NaN          NaN
# 2         3.0           NaN     NaN      NaN         NaN          NaN
# 3       469.0           NaN     NaN      NaN         NaN          NaN
# 4         NaN           NaN     NaN      NaN         NaN          NaN
# ...       ...           ...     ...      ...         ...          ...
# 12750    37.0        4185.0     252   4669.0         NaN          NaN
# 12751   181.0       10678.0     452  11923.0         NaN          1.0
# 12752   121.0       14507.0     470  15707.0         NaN          1.0
# 12753    39.0        3560.0     572   3859.0         NaN          NaN
# 12754     6.0        6300.0       -   6501.0         NaN          6.0
#
#        localOccCnt                 createDt updateDt
# 0              NaN   2020-03-02 19:27:57.57      NaN
# 1              NaN   2020-03-02 19:27:57.57      NaN
# 2              NaN   2020-03-02 19:27:57.57      NaN
# 3              NaN   2020-03-02 19:27:57.57      NaN
# 4              NaN   2020-03-02 19:27:57.57      NaN
# ...            ...                      ...      ...
# 12750         37.0  2021-12-06 09:03:08.448      NaN
# 12751        180.0  2021-12-06 09:03:08.448      NaN
# 12752        120.0  2021-12-06 09:03:08.449      NaN
# 12753         39.0  2021-12-06 09:03:08.449      NaN
# 12754          NaN   2021-12-06 09:03:08.45      NaN
#
# [12755 rows x 15 columns]

# %%
cosurv.columns
# Out:
# Index(['seq', 'stdDay', 'gubun', 'gubunCn', 'gubunEn', 'deathCnt', 'incDec',
#        'isolClearCnt', 'qurRate', 'defCnt', 'isolIngCnt', 'overFlowCnt',
#        'localOccCnt', 'createDt', 'updateDt'],
#       dtype='object')

# %%
cosurv['stdDay'] = pd.to_datetime(cosurv['stdDay'], format=('%Y년 %m월 %d일 %H시'))

def get_month_as_datetime(date):
  return datetime(date.year, date.month, date.day)

cosurv['Time'] = cosurv['stdDay'].apply(get_month_as_datetime)
cosurv.tail()
# Out:
#          seq     stdDay gubun gubunCn           gubunEn  deathCnt  incDec  \
# 12750  13742 2021-12-06    전남      全南      Jeollanam-do      27.0    37.0
# 12751  13743 2021-12-06    경북      庆北  Gyeongsangbuk-do     112.0   181.0
# 12752  13744 2021-12-06    경남      庆南  Gyeongsangnam-do      62.0   121.0
# 12753  13745 2021-12-06    제주      济州              Jeju       9.0    39.0
# 12754  13746 2021-12-06    검역     隔離區         Lazaretto      16.0     6.0
#
#        isolClearCnt qurRate   defCnt  isolIngCnt  overFlowCnt  localOccCnt  \
# 12750        4185.0     252   4669.0         NaN          NaN         37.0
# 12751       10678.0     452  11923.0         NaN          1.0        180.0
# 12752       14507.0     470  15707.0         NaN          1.0        120.0
# 12753        3560.0     572   3859.0         NaN          NaN         39.0
# 12754        6300.0       -   6501.0         NaN          6.0          NaN
#
#                       createDt updateDt       Time
# 12750  2021-12-06 09:03:08.448      NaN 2021-12-06
# 12751  2021-12-06 09:03:08.448      NaN 2021-12-06
# 12752  2021-12-06 09:03:08.449      NaN 2021-12-06
# 12753  2021-12-06 09:03:08.449      NaN 2021-12-06
# 12754   2021-12-06 09:03:08.45      NaN 2021-12-06

# %%
cosurv['Time'] = cosurv['Time'].astype(str)
cosurv['TL'] = cosurv.Time + '_' + cosurv.gubun
cosurv
# Out:
#          seq              stdDay gubun gubunCn           gubunEn  deathCnt  \
# 0          1 2020-03-01 16:00:00    합계     NaN               NaN      18.0
# 1          2 2020-03-01 16:00:00    서울     NaN               NaN       NaN
# 2          3 2020-03-01 16:00:00    부산     NaN               NaN       NaN
# 3          4 2020-03-01 16:00:00    대구     NaN               NaN       9.0
# 4          5 2020-03-01 16:00:00    인천     NaN               NaN       NaN
# ...      ...                 ...   ...     ...               ...       ...
# 12750  13742 2021-12-06 00:00:00    전남      全南      Jeollanam-do      27.0
# 12751  13743 2021-12-06 00:00:00    경북      庆北  Gyeongsangbuk-do     112.0
# 12752  13744 2021-12-06 00:00:00    경남      庆南  Gyeongsangnam-do      62.0
# 12753  13745 2021-12-06 00:00:00    제주      济州              Jeju       9.0
# 12754  13746 2021-12-06 00:00:00    검역     隔離區         Lazaretto      16.0
#
#        incDec  isolClearCnt qurRate   defCnt  isolIngCnt  overFlowCnt  \
# 0       586.0           NaN     NaN      NaN         NaN          NaN
# 1        10.0           NaN     NaN      NaN         NaN          NaN
# 2         3.0           NaN     NaN      NaN         NaN          NaN
# 3       469.0           NaN     NaN      NaN         NaN          NaN
# 4         NaN           NaN     NaN      NaN         NaN          NaN
# ...       ...           ...     ...      ...         ...          ...
# 12750    37.0        4185.0     252   4669.0         NaN          NaN
# 12751   181.0       10678.0     452  11923.0         NaN          1.0
# 12752   121.0       14507.0     470  15707.0         NaN          1.0
# 12753    39.0        3560.0     572   3859.0         NaN          NaN
# 12754     6.0        6300.0       -   6501.0         NaN          6.0
#
#        localOccCnt                 createDt updateDt        Time  \
# 0              NaN   2020-03-02 19:27:57.57      NaN  2020-03-01
# 1              NaN   2020-03-02 19:27:57.57      NaN  2020-03-01
# 2              NaN   2020-03-02 19:27:57.57      NaN  2020-03-01
# 3              NaN   2020-03-02 19:27:57.57      NaN  2020-03-01
# 4              NaN   2020-03-02 19:27:57.57      NaN  2020-03-01
# ...            ...                      ...      ...         ...
# 12750         37.0  2021-12-06 09:03:08.448      NaN  2021-12-06
# 12751        180.0  2021-12-06 09:03:08.448      NaN  2021-12-06
# 12752        120.0  2021-12-06 09:03:08.449      NaN  2021-12-06
# 12753         39.0  2021-12-06 09:03:08.449      NaN  2021-12-06
# 12754          NaN   2021-12-06 09:03:08.45      NaN  2021-12-06
#
#                   TL
# 0      2020-03-01_합계
# 1      2020-03-01_서울
# 2      2020-03-01_부산
# 3      2020-03-01_대구
# 4      2020-03-01_인천
# ...              ...
# 12750  2021-12-06_전남
# 12751  2021-12-06_경북
# 12752  2021-12-06_경남
# 12753  2021-12-06_제주
# 12754  2021-12-06_검역
#
# [12755 rows x 17 columns]

# %%
consurv1 = cosurv[cosurv['gubun'] == '서울']
consurv2 = cosurv[cosurv['gubun'] == '대구']
consurv3 = cosurv[cosurv['gubun'] == '부산']
consurv4 = cosurv[cosurv['gubun'] == '광주']
consurv15 = cosurv[cosurv['gubun'] == '대전']

# %%
consurv1['daily_coro'] = consurv1['defCnt'].diff()
consurv2['daily_coro'] = consurv2['defCnt'].diff()
consurv3['daily_coro'] = consurv3['defCnt'].diff()
consurv4['daily_coro'] = consurv4['defCnt'].diff()
consurv15['daily_coro'] = consurv15['defCnt'].diff()

# %%
consurv5 = pd.concat([consurv1, consurv2])
consurv6 = pd.concat([consurv5, consurv3])
consurv7 = pd.concat([consurv6, consurv4])
cosurv = pd.concat([consurv7, consurv15])
df_sorted_by_values = cosurv.sort_values(by='TL' ,ascending=False)
cosurv
# Out:
#          seq              stdDay gubun gubunCn  gubunEn  deathCnt  incDec  \
# 1          2 2020-03-01 16:00:00    서울     NaN      NaN       NaN    10.0
# 20        21 2020-03-04 00:00:00    서울     NaN      NaN       NaN     1.0
# 38        39 2020-03-05 00:00:00    서울     NaN      NaN       NaN     4.0
# 56        57 2020-03-06 00:00:00    서울     NaN      NaN       NaN     2.0
# 74        75 2020-03-07 00:00:00    서울     NaN      NaN       NaN     3.0
# ...      ...                 ...   ...     ...      ...       ...     ...
# 12666  13639 2021-12-02 00:00:00    대전      大田  Daejeon      70.0   166.0
# 12685  13677 2021-12-03 00:00:00    대전      大田  Daejeon      71.0    97.0
# 12704  13696 2021-12-04 00:00:00    대전      大田  Daejeon      71.0   126.0
# 12723  13715 2021-12-05 00:00:00    대전      大田  Daejeon      73.0   142.0
# 12742  13734 2021-12-06 00:00:00    대전      大田  Daejeon      74.0   106.0
#
#        isolClearCnt qurRate  defCnt  isolIngCnt  overFlowCnt  localOccCnt  \
# 1               NaN     NaN     NaN         NaN          NaN          NaN
# 20              NaN       1    99.0         NaN          NaN          NaN
# 38              NaN     1.1   103.0         NaN          NaN          NaN
# 56              NaN     1.1   105.0         NaN          NaN          NaN
# 74              NaN     1.1   108.0         NaN          NaN          NaN
# ...             ...     ...     ...         ...          ...          ...
# 12666        8033.0     602  8809.0       706.0          NaN        166.0
# 12685        8083.0     608  8906.0         NaN          NaN         97.0
# 12704        8136.0     617  9032.0         NaN          NaN        126.0
# 12723        8163.0     627  9174.0         NaN          1.0        141.0
# 12742        8191.0     634  9280.0         NaN          NaN        106.0
#
#                       createDt                updateDt        Time  \
# 1       2020-03-02 19:27:57.57                     NaN  2020-03-01
# 20      2020-03-04 19:44:27.27                     NaN  2020-03-04
# 38      2020-03-05 15:29:39.39  2020-03-05 21:05:30.30  2020-03-05
# 56      2020-03-06 15:09:04.04                     NaN  2020-03-06
# 74      2020-03-07 15:29:59.59                     NaN  2020-03-07
# ...                        ...                     ...         ...
# 12666   2021-12-02 09:02:44.57                     NaN  2021-12-02
# 12685  2021-12-03 09:10:27.044                     NaN  2021-12-03
# 12704  2021-12-04 09:17:37.916                     NaN  2021-12-04
# 12723  2021-12-05 08:47:30.291                     NaN  2021-12-05
# 12742  2021-12-06 09:03:08.443                     NaN  2021-12-06
#
#                   TL  daily_coro
# 1      2020-03-01_서울         NaN
# 20     2020-03-04_서울         NaN
# 38     2020-03-05_서울         4.0
# 56     2020-03-06_서울         2.0
# 74     2020-03-07_서울         3.0
# ...              ...         ...
# 12666  2021-12-02_대전       166.0
# 12685  2021-12-03_대전        97.0
# 12704  2021-12-04_대전       126.0
# 12723  2021-12-05_대전       142.0
# 12742  2021-12-06_대전       106.0
#
# [3360 rows x 18 columns]

# %%
cosurv = cosurv[pd.notnull(cosurv['daily_coro'])]
cosurv
# Out:
#          seq     stdDay gubun gubunCn  gubunEn  deathCnt  incDec  \
# 38        39 2020-03-05    서울     NaN      NaN       NaN     4.0
# 56        57 2020-03-06    서울     NaN      NaN       NaN     2.0
# 74        75 2020-03-07    서울     NaN      NaN       NaN     3.0
# 92        93 2020-03-08    서울     NaN      NaN       NaN    12.0
# 110      111 2020-03-09    서울     NaN      NaN       NaN    10.0
# ...      ...        ...   ...     ...      ...       ...     ...
# 12666  13639 2021-12-02    대전      大田  Daejeon      70.0   166.0
# 12685  13677 2021-12-03    대전      大田  Daejeon      71.0    97.0
# 12704  13696 2021-12-04    대전      大田  Daejeon      71.0   126.0
# 12723  13715 2021-12-05    대전      大田  Daejeon      73.0   142.0
# 12742  13734 2021-12-06    대전      大田  Daejeon      74.0   106.0
#
#        isolClearCnt qurRate  defCnt  isolIngCnt  overFlowCnt  localOccCnt  \
# 38              NaN     1.1   103.0         NaN          NaN          NaN
# 56              NaN     1.1   105.0         NaN          NaN          NaN
# 74              NaN     1.1   108.0         NaN          NaN          NaN
# 92              NaN     1.2   120.0         NaN          NaN          NaN
# 110            29.0     1.3   130.0         NaN          NaN          NaN
# ...             ...     ...     ...         ...          ...          ...
# 12666        8033.0     602  8809.0       706.0          NaN        166.0
# 12685        8083.0     608  8906.0         NaN          NaN         97.0
# 12704        8136.0     617  9032.0         NaN          NaN        126.0
# 12723        8163.0     627  9174.0         NaN          1.0        141.0
# 12742        8191.0     634  9280.0         NaN          NaN        106.0
#
#                       createDt                updateDt        Time  \
# 38      2020-03-05 15:29:39.39  2020-03-05 21:05:30.30  2020-03-05
# 56      2020-03-06 15:09:04.04                     NaN  2020-03-06
# 74      2020-03-07 15:29:59.59                     NaN  2020-03-07
# 92      2020-03-08 14:56:02.02                     NaN  2020-03-08
# 110     2020-03-09 12:54:29.29                     NaN  2020-03-09
# ...                        ...                     ...         ...
# 12666   2021-12-02 09:02:44.57                     NaN  2021-12-02
# 12685  2021-12-03 09:10:27.044                     NaN  2021-12-03
# 12704  2021-12-04 09:17:37.916                     NaN  2021-12-04
# 12723  2021-12-05 08:47:30.291                     NaN  2021-12-05
# 12742  2021-12-06 09:03:08.443                     NaN  2021-12-06
#
#                   TL  daily_coro
# 38     2020-03-05_서울         4.0
# 56     2020-03-06_서울         2.0
# 74     2020-03-07_서울         3.0
# 92     2020-03-08_서울        12.0
# 110    2020-03-09_서울        10.0
# ...              ...         ...
# 12666  2021-12-02_대전       166.0
# 12685  2021-12-03_대전        97.0
# 12704  2021-12-04_대전       126.0
# 12723  2021-12-05_대전       142.0
# 12742  2021-12-06_대전       106.0
#
# [3342 rows x 18 columns]

# %%
cosurv_columns = ['gubun', 'daily_coro', 'Time', 'TL']
cosurv = cosurv[cosurv_columns]
cosurv = cosurv[cosurv['gubun'] != '합계']
cosurv
# Out:
#       gubun  daily_coro        Time             TL
# 38       서울         4.0  2020-03-05  2020-03-05_서울
# 56       서울         2.0  2020-03-06  2020-03-06_서울
# 74       서울         3.0  2020-03-07  2020-03-07_서울
# 92       서울        12.0  2020-03-08  2020-03-08_서울
# 110      서울        10.0  2020-03-09  2020-03-09_서울
# ...     ...         ...         ...            ...
# 12666    대전       166.0  2021-12-02  2021-12-02_대전
# 12685    대전        97.0  2021-12-03  2021-12-03_대전
# 12704    대전       126.0  2021-12-04  2021-12-04_대전
# 12723    대전       142.0  2021-12-05  2021-12-05_대전
# 12742    대전       106.0  2021-12-06  2021-12-06_대전
#
# [3342 rows x 4 columns]

# %%
cosurv.rename(columns = {"gubun": "Location", "daily_coro": "일일확진자", 'Time' : 'Time', 'TL' : 'TL'}, inplace=True)
cosurv
# Out:
#       Location  일일확진자        Time             TL
# 38          서울    4.0  2020-03-05  2020-03-05_서울
# 56          서울    2.0  2020-03-06  2020-03-06_서울
# 74          서울    3.0  2020-03-07  2020-03-07_서울
# 92          서울   12.0  2020-03-08  2020-03-08_서울
# 110         서울   10.0  2020-03-09  2020-03-09_서울
# ...        ...    ...         ...            ...
# 12666       대전  166.0  2021-12-02  2021-12-02_대전
# 12685       대전   97.0  2021-12-03  2021-12-03_대전
# 12704       대전  126.0  2021-12-04  2021-12-04_대전
# 12723       대전  142.0  2021-12-05  2021-12-05_대전
# 12742       대전  106.0  2021-12-06  2021-12-06_대전
#
# [3342 rows x 4 columns]

# %%
cosurv = cosurv.sort_index(ascending=True)
cosurv['일일확진자'][(cosurv['일일확진자'] < 0)] = 0  
cosurv
# Out:
#       Location   일일확진자        Time             TL
# 38          서울     4.0  2020-03-05  2020-03-05_서울
# 39          부산     0.0  2020-03-05  2020-03-05_부산
# 40          대구   321.0  2020-03-05  2020-03-05_대구
# 42          광주     1.0  2020-03-05  2020-03-05_광주
# 43          대전     1.0  2020-03-05  2020-03-05_대전
# ...        ...     ...         ...            ...
# 12737       서울  1408.0  2021-12-06  2021-12-06_서울
# 12738       부산   193.0  2021-12-06  2021-12-06_부산
# 12739       대구   146.0  2021-12-06  2021-12-06_대구
# 12741       광주    43.0  2021-12-06  2021-12-06_광주
# 12742       대전   106.0  2021-12-06  2021-12-06_대전
#
# [3342 rows x 4 columns]

# %%
coseoul = cosurv[cosurv['Location'] == '서울']
coseoul = coseoul.replace(0, np.NaN)
coseoul = coseoul.fillna(method = 'pad')
coseoul
# Out:
#       Location   일일확진자        Time             TL
# 38          서울     4.0  2020-03-05  2020-03-05_서울
# 56          서울     2.0  2020-03-06  2020-03-06_서울
# 74          서울     3.0  2020-03-07  2020-03-07_서울
# 92          서울    12.0  2020-03-08  2020-03-08_서울
# 110         서울    10.0  2020-03-09  2020-03-09_서울
# ...        ...     ...         ...            ...
# 12661       서울  2267.0  2021-12-02  2021-12-02_서울
# 12680       서울  2099.0  2021-12-03  2021-12-03_서울
# 12699       서울  2273.0  2021-12-04  2021-12-04_서울
# 12718       서울  2032.0  2021-12-05  2021-12-05_서울
# 12737       서울  1408.0  2021-12-06  2021-12-06_서울
#
# [670 rows x 4 columns]

# %%
cog = cosurv[cosurv['Location'] == '광주']
cog = cog.replace(0, np.NaN)
cog = cog.fillna(method = 'pad')
cog
# Out:
#       Location  일일확진자        Time             TL
# 42          광주    1.0  2020-03-05  2020-03-05_광주
# 60          광주    1.0  2020-03-06  2020-03-06_광주
# 78          광주    1.0  2020-03-07  2020-03-07_광주
# 96          광주    1.0  2020-03-08  2020-03-08_광주
# 114         광주    2.0  2020-03-09  2020-03-09_광주
# ...        ...    ...         ...            ...
# 12665       광주   39.0  2021-12-02  2021-12-02_광주
# 12684       광주   45.0  2021-12-03  2021-12-03_광주
# 12703       광주   39.0  2021-12-04  2021-12-04_광주
# 12722       광주   40.0  2021-12-05  2021-12-05_광주
# 12741       광주   43.0  2021-12-06  2021-12-06_광주
#
# [666 rows x 4 columns]

# %%
cod = cosurv[cosurv['Location'] == '대구']
cod = cod.replace(0, np.NaN)
cod = cod.fillna(method = 'pad')
cod
# Out:
#       Location  일일확진자        Time             TL
# 40          대구  321.0  2020-03-05  2020-03-05_대구
# 58          대구  367.0  2020-03-06  2020-03-06_대구
# 76          대구  390.0  2020-03-07  2020-03-07_대구
# 94          대구  297.0  2020-03-08  2020-03-08_대구
# 112         대구  190.0  2020-03-09  2020-03-09_대구
# ...        ...    ...         ...            ...
# 12663       대구   70.0  2021-12-02  2021-12-02_대구
# 12682       대구   99.0  2021-12-03  2021-12-03_대구
# 12701       대구   90.0  2021-12-04  2021-12-04_대구
# 12720       대구  117.0  2021-12-05  2021-12-05_대구
# 12739       대구  146.0  2021-12-06  2021-12-06_대구
#
# [670 rows x 4 columns]

# %%
cob = cosurv[cosurv['Location'] == '부산']
cob = cob.replace(0, np.NaN)
cob = cob.fillna(method = 'pad')
cob
# Out:
#       Location  일일확진자        Time             TL
# 39          부산    NaN  2020-03-05  2020-03-05_부산
# 57          부산    3.0  2020-03-06  2020-03-06_부산
# 75          부산    1.0  2020-03-07  2020-03-07_부산
# 93          부산    1.0  2020-03-08  2020-03-08_부산
# 111         부산    1.0  2020-03-09  2020-03-09_부산
# ...        ...    ...         ...            ...
# 12662       부산  158.0  2021-12-02  2021-12-02_부산
# 12681       부산  141.0  2021-12-03  2021-12-03_부산
# 12700       부산  201.0  2021-12-04  2021-12-04_부산
# 12719       부산  207.0  2021-12-05  2021-12-05_부산
# 12738       부산  193.0  2021-12-06  2021-12-06_부산
#
# [670 rows x 4 columns]

# %%
coj = cosurv[cosurv['Location'] == '대전']
coj = coj.replace(0, np.NaN)
coj = coj.fillna(method = 'pad')
coj
# Out:
#       Location  일일확진자        Time             TL
# 43          대전    1.0  2020-03-05  2020-03-05_대전
# 61          대전    2.0  2020-03-06  2020-03-06_대전
# 79          대전    2.0  2020-03-07  2020-03-07_대전
# 97          대전    2.0  2020-03-08  2020-03-08_대전
# 115         대전    1.0  2020-03-09  2020-03-09_대전
# ...        ...    ...         ...            ...
# 12666       대전  166.0  2021-12-02  2021-12-02_대전
# 12685       대전   97.0  2021-12-03  2021-12-03_대전
# 12704       대전  126.0  2021-12-04  2021-12-04_대전
# 12723       대전  142.0  2021-12-05  2021-12-05_대전
# 12742       대전  106.0  2021-12-06  2021-12-06_대전
#
# [666 rows x 4 columns]

# %%
consurv5 = pd.concat([coseoul, cod])
consurv6 = pd.concat([consurv5, coj])
consurv7 = pd.concat([consurv6, cob])
cosurv = pd.concat([consurv7, cog])
df_sorted_by_values = cosurv.sort_values(by='TL' ,ascending=False)
cosurv
# Out:
#       Location  일일확진자        Time             TL
# 38          서울    4.0  2020-03-05  2020-03-05_서울
# 56          서울    2.0  2020-03-06  2020-03-06_서울
# 74          서울    3.0  2020-03-07  2020-03-07_서울
# 92          서울   12.0  2020-03-08  2020-03-08_서울
# 110         서울   10.0  2020-03-09  2020-03-09_서울
# ...        ...    ...         ...            ...
# 12665       광주   39.0  2021-12-02  2021-12-02_광주
# 12684       광주   45.0  2021-12-03  2021-12-03_광주
# 12703       광주   39.0  2021-12-04  2021-12-04_광주
# 12722       광주   40.0  2021-12-05  2021-12-05_광주
# 12741       광주   43.0  2021-12-06  2021-12-06_광주
#
# [3342 rows x 4 columns]

# %%
cosurv = cosurv.sort_index(ascending=True)
cosurv
# Out:
#       Location   일일확진자        Time             TL
# 38          서울     4.0  2020-03-05  2020-03-05_서울
# 39          부산     NaN  2020-03-05  2020-03-05_부산
# 40          대구   321.0  2020-03-05  2020-03-05_대구
# 42          광주     1.0  2020-03-05  2020-03-05_광주
# 43          대전     1.0  2020-03-05  2020-03-05_대전
# ...        ...     ...         ...            ...
# 12737       서울  1408.0  2021-12-06  2021-12-06_서울
# 12738       부산   193.0  2021-12-06  2021-12-06_부산
# 12739       대구   146.0  2021-12-06  2021-12-06_대구
# 12741       광주    43.0  2021-12-06  2021-12-06_광주
# 12742       대전   106.0  2021-12-06  2021-12-06_대전
#
# [3342 rows x 4 columns]

# %%
input_file = r'C:\KDK\python\data\corona\Tall' 
output_file = r'C:\KDK\python\data\corona\Tall\tall.csv' 

allFile_list = glob.glob(os.path.join(input_file, 'Tall_*')) 
print(allFile_list)
allData = [] 
for file in allFile_list:
    df = pd.read_csv(file) 
    allData.append(df)

dataCombine = pd.concat(allData, axis=0, ignore_index=True) 
dataCombine.to_csv(output_file, index=False)
# Out:
# ['C:\\KDK\\python\\data\\corona\\Tall\\Tall_2020_1.csv', 'C:\\KDK\\python\\data\\corona\\Tall\\Tall_2020_2.csv', 'C:\\KDK\\python\\data\\corona\\Tall\\Tall_2020_3.csv', 'C:\\KDK\\python\\data\\corona\\Tall\\Tall_2020_4.csv', 'C:\\KDK\\python\\data\\corona\\Tall\\Tall_2021_1.csv', 'C:\\KDK\\python\\data\\corona\\Tall\\Tall_2021_2.csv', 'C:\\KDK\\python\\data\\corona\\Tall\\Tall_2021_3.csv']

# %%
tall = pd.read_csv('./data/corona/tall/Tall.csv')
tall
# Out:
#             집계일자  영업소코드   영업소명  입출구구분코드 입출구명  TCS하이패스구분코드 TCS하이패스명  \
# 0       20200101    246     가락        0   입구            1      TCS
# 1       20200101    246     가락        0   입구            2  hi-pass
# 2       20200101     29  가락(개)        0   입구            1      TCS
# 3       20200101     29  가락(개)        0   입구            2  hi-pass
# 4       20200101     29  가락(개)        1   출구            1      TCS
# ...          ...    ...    ...      ...  ...          ...      ...
# 899385  20210930    532     회인        1   출구            2  hi-pass
# 899386  20210930    216     횡성        0   입구            1      TCS
# 899387  20210930    216     횡성        0   입구            2  hi-pass
# 899388  20210930    216     횡성        1   출구            1      TCS
# 899389  20210930    216     횡성        1   출구            2  hi-pass
#
#         고속도로운영기관구분코드 고속도로운영기관명  영업형태구분코드 영업형태명  1종교통량  2종교통량  3종교통량  4종교통량  \
# 0                  0    한국도로공사         0   폐쇄식    147      2      3     13
# 1                  0    한국도로공사         0   폐쇄식    311      2      9     16
# 2                  0    한국도로공사         1   개방식   1769     20     40     49
# 3                  0    한국도로공사         1   개방식   8312     26     72     40
# 4                  0    한국도로공사         1   개방식   2383     33     40     46
# ...              ...       ...       ...   ...    ...    ...    ...    ...
# 899385             0    한국도로공사         0   폐쇄식    947     20     13     13
# 899386             0    한국도로공사         0   폐쇄식    487     26     50     45
# 899387             0    한국도로공사         0   폐쇄식   2941    139     84    110
# 899388             0    한국도로공사         0   폐쇄식    466     31     82     39
# 899389             0    한국도로공사         0   폐쇄식   2919    133     82     81
#
#         5종교통량  6종교통량  총교통량
# 0           8      9   182
# 1          74      8   420
# 2         120    260  2258
# 3         499    444  9393
# 4         141    322  2965
# ...       ...    ...   ...
# 899385     72     32  1097
# 899386      7      5   620
# 899387    161    156  3591
# 899388      7     51   676
# 899389    170    147  3532
#
# [899390 rows x 18 columns]

# %%
tall_columns = ['집계일자', '영업소명', '총교통량']
tall = tall[tall_columns]
tall1 = tall.groupby(by=['집계일자','영업소명']).sum()
tall1.to_csv('./data/corona/tall/tallgate.csv')
tall2 = pd.read_csv('./data/corona/tall/tallgate.csv')
tall2
# Out:
#             집계일자   영업소명   총교통량
# 0       20200101     가락    602
# 1       20200101  가락(개)  25144
# 2       20200101    가락2    966
# 3       20200101     가산  19487
# 4       20200101     가조   3452
# ...          ...    ...    ...
# 234650  20210930     활천   4253
# 234651  20210930     황간   3764
# 234652  20210930     황전   3550
# 234653  20210930     회인   2582
# 234654  20210930     횡성   8419
#
# [234655 rows x 3 columns]

# %%
seoul = ['북고양','양주','불암산','화도','일산대교','김포','구리남양주','남산1호터널','인천','동서울','시흥','금천','우면산터널','성남','고잔','남안산','서서울','의왕','서울','초월']
daegu = ['칠곡','북대구','팔공산','서대구','남대구','앞산','동대구','수성','경산','청통와촌']
busan = ['광재','김해부산','남양산','부산','장안','기장일광','해운대','광안대로','대동','북부산','백양터널','서부산','명지','영도']
gyangju = ['장성','담양','광주','북광주','창평','동광주','유덕IC','동광산','서광산','송암','소태']
daejun = ['대전', '유성', '서대전', '남세종', '신탄진', '옥천', '추부']

def convert(data):
    if data in seoul:
        return '서울'
    elif data in daegu:
        return '대구'
    elif data in busan:
        return '부산'
    elif data in gyangju:
        return '광주'
    elif data in daejun:
        return '대전'
    else :
        return '그외'

tall2['영업소명'] = tall2['영업소명'].apply(convert)
tall2 = tall2[tall2['영업소명'] != '그외']
tall2
# Out:
#             집계일자 영업소명    총교통량
# 11      20200101   대구   21435
# 24      20200101   부산   10244
# 25      20200101   광주   37511
# 29      20200101   서울  156514
# 53      20200101   서울  151930
# ...          ...  ...     ...
# 234604  20210930   광주    5441
# 234611  20210930   대구   13189
# 234612  20210930   대전    8669
# 234618  20210930   대구   29855
# 234629  20210930   대구   30978
#
# [22158 rows x 3 columns]

# %%
tall3 = tall2.groupby(by=['집계일자','영업소명']).sum()
tall3.to_csv('./data/corona/tall/tallgate.csv')
tall4 = pd.read_csv('./data/corona/tall/tallgate.csv')
tall4
# Out:
#           집계일자 영업소명     총교통량
# 0     20200101   광주   163710
# 1     20200101   대구   239039
# 2     20200101   대전   160113
# 3     20200101   부산   302030
# 4     20200101   서울  1090782
# ...        ...  ...      ...
# 3185  20210930   광주   191529
# 3186  20210930   대구   330743
# 3187  20210930   대전   222045
# 3188  20210930   부산   368175
# 3189  20210930   서울  1497078
#
# [3190 rows x 3 columns]

# %%
tall4['Time'] = pd.to_datetime(tall4['집계일자'], format=('%Y%m%d'))
tall4_columns = ['Time', '영업소명', '총교통량']
tall4 = tall4[tall4_columns]

# %%
tall4.rename(columns = {"Time": "Time", "영업소명": "Location", '총교통량' : '총교통량'}, inplace=True)
tall4
# Out:
#            Time Location     총교통량
# 0    2020-01-01       광주   163710
# 1    2020-01-01       대구   239039
# 2    2020-01-01       대전   160113
# 3    2020-01-01       부산   302030
# 4    2020-01-01       서울  1090782
# ...         ...      ...      ...
# 3185 2021-09-30       광주   191529
# 3186 2021-09-30       대구   330743
# 3187 2021-09-30       대전   222045
# 3188 2021-09-30       부산   368175
# 3189 2021-09-30       서울  1497078
#
# [3190 rows x 3 columns]

# %%
input_file = r'C:\KDK\python\data\corona\Tall\ttt' 
output_file = r'C:\KDK\python\data\corona\Tall\ttt\t_tall.csv' 

allFile_list = glob.glob(os.path.join(input_file, 'tall_*')) 
print(allFile_list)
allData = [] 
for file in allFile_list:
    df = pd.read_csv(file) 
    allData.append(df)

dataCombine = pd.concat(allData, axis=0, ignore_index=True) 
dataCombine.to_csv(output_file, index=False)
# Out:
# ['C:\\KDK\\python\\data\\corona\\Tall\\ttt\\tall_2021_10.csv', 'C:\\KDK\\python\\data\\corona\\Tall\\ttt\\tall_2021_11.csv']

# %%
t_tall = pd.read_csv('./data/corona/Tall/ttt/tall.csv')
t_tall
# Out:
#            집계일자  영업소코드  입출구구분코드  TCS하이패스구분코드  고속도로운영기관구분코드  영업형태구분코드  1종교통량  \
# 0      20211001     11        0            1             0         1   8133
# 1      20211001     11        0            2             0         1  67014
# 2      20211001     11        1            1             0         1   9050
# 3      20211001     11        1            2             0         1  70167
# 4      20211001     12        0            1             0         1    282
# ...         ...    ...      ...          ...           ...       ...    ...
# 97561  20211128    986        1            2             0         0   3361
# 97562  20211128    987        0            1             0         0   1772
# 97563  20211128    987        0            2             0         0  10230
# 97564  20211128    987        1            1             0         0   2044
# 97565  20211128    987        1            2             0         0  11326
#
#        2종교통량  3종교통량  4종교통량  5종교통량  6종교통량   총교통량  Unnamed: 13
# 0        407    512    650    683   1213  11598          NaN
# 1       1900    644    767   2218   4352  76895          NaN
# 2        279    658    626    374   1312  12299          NaN
# 3       1957    741    921   2635   4666  81087          NaN
# 4          8     14     10      4     18    336          NaN
# ...      ...    ...    ...    ...    ...    ...          ...
# 97561     20     65     29     65     71   3611          NaN
# 97562     32     73     39     20     15   1951          NaN
# 97563     61    181     84    331    232  11119          NaN
# 97564     19     22     76     31    141   2333          NaN
# 97565     63    203    222    359    251  12424          NaN
#
# [97566 rows x 14 columns]

# %%
tall_columns = ['집계일자', '영업소코드', '총교통량']
t_tall = t_tall[tall_columns]
t_tall1 = t_tall.groupby(by=['집계일자','영업소코드']).sum()
t_tall1.to_csv('./data/corona/tall/ttt/t_tallgate.csv')
t_tall2 = pd.read_csv('./data/corona/tall/ttt/t_tallgate.csv')
t_tall2.head(20)
# Out:
#         집계일자  영업소코드    총교통량
# 0   20211001     11  181879
# 1   20211001     12    2956
# 2   20211001     13    7638
# 3   20211001     25   15379
# 4   20211001     29   44405
# 5   20211001     53   89926
# 6   20211001     56    1599
# 7   20211001     61  203825
# 8   20211001     62  213577
# 9   20211001     63   33186
# 10  20211001     64  181529
# 11  20211001     65   94540
# 12  20211001     66   36765
# 13  20211001     67  166327
# 14  20211001     68  198978
# 15  20211001     69    8999
# 16  20211001     74   19369
# 17  20211001     91    6648
# 18  20211001     92   10510
# 19  20211001    101  214055

# %%
seoul = [11, 61, 62, 67, 68, 101, 190, 253]
daegu = [127,129,131,201,230,519,524]
busan = [140, 150, 244,250,252, 755]
gyangju = [166,167,249,261,262,552,553,569]
daejun = [115, 152, 153, 579, 113, 116, 204]

def t_convert(data):
    if data in seoul:
        return '서울'
    elif data in daegu:
        return '대구'
    elif data in busan:
        return '부산'
    elif data in gyangju:
        return '광주'
    elif data in daejun:
        return '대전'
    else :
        return '그외'

t_tall2['영업소코드'] = t_tall2['영업소코드'].apply(t_convert)
t_tall2 = t_tall2[t_tall2['영업소코드'] != '그외']
t_tall2
# Out:
#            집계일자 영업소코드    총교통량
# 0      20211001    서울  181879
# 7      20211001    서울  203825
# 8      20211001    서울  213577
# 13     20211001    서울  166327
# 14     20211001    서울  198978
# ...         ...   ...     ...
# 25526  20211130    광주   13728
# 25527  20211130    광주   41680
# 25543  20211130    광주   17312
# 25553  20211130    대전   18118
# 25657  20211130    부산   17633
#
# [2196 rows x 3 columns]

# %%
t_tall3 = t_tall2.groupby(by=['집계일자','영업소코드']).sum()
t_tall3.to_csv('./data/corona/tall/ttt/t_tallgate.csv')
t_tall4 = pd.read_csv('./data/corona/tall/ttt/t_tallgate.csv')
t_tall4
# Out:
#          집계일자 영업소코드     총교통량
# 0    20211001    광주   214442
# 1    20211001    대구   354352
# 2    20211001    대전   238696
# 3    20211001    부산   404042
# 4    20211001    서울  1557002
# ..        ...   ...      ...
# 300  20211130    광주   167934
# 301  20211130    대구   299925
# 302  20211130    대전   197423
# 303  20211130    부산   340303
# 304  20211130    서울  1333431
#
# [305 rows x 3 columns]

# %%
t_tall4['Time'] = pd.to_datetime(t_tall4['집계일자'], format=('%Y%m%d'))
t_tall4_columns = ['Time', '영업소코드', '총교통량']
t_tall4 = t_tall4[t_tall4_columns]

# %%
t_tall4.rename(columns = {"Time": "Time", "영업소코드": "Location", '총교통량' : '총교통량'}, inplace=True)
t_tall4
# Out:
#           Time Location     총교통량
# 0   2021-10-01       광주   214442
# 1   2021-10-01       대구   354352
# 2   2021-10-01       대전   238696
# 3   2021-10-01       부산   404042
# 4   2021-10-01       서울  1557002
# ..         ...      ...      ...
# 300 2021-11-30       광주   167934
# 301 2021-11-30       대구   299925
# 302 2021-11-30       대전   197423
# 303 2021-11-30       부산   340303
# 304 2021-11-30       서울  1333431
#
# [305 rows x 3 columns]

# %%
tall4 = pd.concat([tall4, t_tall4])
tall4
# Out:
#           Time Location     총교통량
# 0   2020-01-01       광주   163710
# 1   2020-01-01       대구   239039
# 2   2020-01-01       대전   160113
# 3   2020-01-01       부산   302030
# 4   2020-01-01       서울  1090782
# ..         ...      ...      ...
# 300 2021-11-30       광주   167934
# 301 2021-11-30       대구   299925
# 302 2021-11-30       대전   197423
# 303 2021-11-30       부산   340303
# 304 2021-11-30       서울  1333431
#
# [3495 rows x 3 columns]

# %%
tall4['Time'] = tall4['Time'].astype(str)
tall4['TL'] = tall4.Time + '_' + tall4.Location
tall4
# Out:
#            Time Location     총교통량             TL
# 0    2020-01-01       광주   163710  2020-01-01_광주
# 1    2020-01-01       대구   239039  2020-01-01_대구
# 2    2020-01-01       대전   160113  2020-01-01_대전
# 3    2020-01-01       부산   302030  2020-01-01_부산
# 4    2020-01-01       서울  1090782  2020-01-01_서울
# ..          ...      ...      ...            ...
# 300  2021-11-30       광주   167934  2021-11-30_광주
# 301  2021-11-30       대구   299925  2021-11-30_대구
# 302  2021-11-30       대전   197423  2021-11-30_대전
# 303  2021-11-30       부산   340303  2021-11-30_부산
# 304  2021-11-30       서울  1333431  2021-11-30_서울
#
# [3495 rows x 4 columns]

# %%
df_sorted_by_values = tall4.sort_values(by='TL' ,ascending=False)
tall4
# Out:
#            Time Location     총교통량             TL
# 0    2020-01-01       광주   163710  2020-01-01_광주
# 1    2020-01-01       대구   239039  2020-01-01_대구
# 2    2020-01-01       대전   160113  2020-01-01_대전
# 3    2020-01-01       부산   302030  2020-01-01_부산
# 4    2020-01-01       서울  1090782  2020-01-01_서울
# ..          ...      ...      ...            ...
# 300  2021-11-30       광주   167934  2021-11-30_광주
# 301  2021-11-30       대구   299925  2021-11-30_대구
# 302  2021-11-30       대전   197423  2021-11-30_대전
# 303  2021-11-30       부산   340303  2021-11-30_부산
# 304  2021-11-30       서울  1333431  2021-11-30_서울
#
# [3495 rows x 4 columns]

# %%
vaccine = pd.read_csv('./data/corona/Covid19Vaccine01.csv')
vaccine = vaccine.fillna(0)
vaccine
# Out:
#                    seq             baseDate     sido  firstCnt  secondCnt  \
# 0         20210311_강원도  2021-03-11 00:00:00      강원도    2627.0        0.0
# 1         20210311_경기도  2021-03-11 00:00:00      경기도    9961.0        0.0
# 2        20210311_경상남도  2021-03-11 00:00:00     경상남도    2036.0        0.0
# 3        20210311_경상북도  2021-03-11 00:00:00     경상북도    2365.0        0.0
# 4       20210311_광주광역시  2021-03-11 00:00:00    광주광역시    2403.0        0.0
# ...                ...                  ...      ...       ...        ...
# 4879     20211206_전라남도  2021-12-06 00:00:00     전라남도      13.0       29.0
# 4880     20211206_전라북도  2021-12-06 00:00:00     전라북도      37.0       34.0
# 4881  20211206_제주특별자치도  2021-12-06 00:00:00  제주특별자치도      33.0       20.0
# 4882     20211206_충청남도  2021-12-06 00:00:00     충청남도      33.0       62.0
# 4883     20211206_충청북도  2021-12-06 00:00:00     충청북도      28.0       32.0
#
#       totalFirstCnt  totalSecondCnt  accumulatedFirstCnt  accumulatedSecondCnt
# 0             14790             0.0                12163                   0.0
# 1            105876             0.0                95915                   0.0
# 2             43848             0.0                41812                   0.0
# 3             28435             0.0                26070                   0.0
# 4             22683             0.0                20280                   0.0
# ...             ...             ...                  ...                   ...
# 4879        1577132       1525475.0              1577119             1525446.0
# 4880        1516390       1465954.0              1516353             1465920.0
# 4881         550516        531391.0               550483              531371.0
# 4882        1792133       1731542.0              1792100             1731480.0
# 4883        1353724       1311624.0              1353696             1311592.0
#
# [4884 rows x 9 columns]

# %%
def SD(sido):
    if sido == '광주광역시':
        return '광주'
    elif sido == '대구광역시':
        return '대구'
    elif sido == '부산광역시':
        return '부산'
    elif sido == '서울특별시':
        return '서울'
    elif sido == '대전광역시':
        return '대전'
    else :
        return '그외'

# %%
vaccine['sido'] = vaccine['sido'].apply(SD)

# %%
vaccine = vaccine[vaccine['sido'] != '그외']
vaccine
# Out:
#                  seq             baseDate sido  firstCnt  secondCnt  \
# 4     20210311_광주광역시  2021-03-11 00:00:00   광주    2403.0        0.0
# 5     20210311_대구광역시  2021-03-11 00:00:00   대구    2310.0        0.0
# 6     20210311_대전광역시  2021-03-11 00:00:00   대전    1952.0        0.0
# 7     20210311_부산광역시  2021-03-11 00:00:00   부산    3311.0        0.0
# 8     20210311_서울특별시  2021-03-11 00:00:00   서울   12595.0        0.0
# ...              ...                  ...  ...       ...        ...
# 4870  20211206_광주광역시  2021-12-06 00:00:00   광주      16.0       22.0
# 4871  20211206_대구광역시  2021-12-06 00:00:00   대구      35.0       36.0
# 4872  20211206_대전광역시  2021-12-06 00:00:00   대전      40.0       28.0
# 4873  20211206_부산광역시  2021-12-06 00:00:00   부산      85.0       92.0
# 4874  20211206_서울특별시  2021-12-06 00:00:00   서울     346.0      400.0
#
#       totalFirstCnt  totalSecondCnt  accumulatedFirstCnt  accumulatedSecondCnt
# 4             22683             0.0                20280                   0.0
# 5             25411             0.0                23101                   0.0
# 6             14525             0.0                12573                   0.0
# 7             40045             0.0                36734                   0.0
# 8             73827             0.0                61232                   0.0
# ...             ...             ...                  ...                   ...
# 4870        1191925       1148110.0              1191909             1148088.0
# 4871        1898227       1835971.0              1898192             1835935.0
# 4872        1175320       1136378.0              1175280             1136350.0
# 4873        2727591       2639817.0              2727506             2639725.0
# 4874        7945695       7723156.0              7945349             7722756.0
#
# [1355 rows x 9 columns]

# %%
def time_convert(date):
    a, b = str(date).split(' ')
    return a
vaccine['Time'] = vaccine['baseDate'].apply(time_convert)
vaccine
# Out:
#                  seq             baseDate sido  firstCnt  secondCnt  \
# 4     20210311_광주광역시  2021-03-11 00:00:00   광주    2403.0        0.0
# 5     20210311_대구광역시  2021-03-11 00:00:00   대구    2310.0        0.0
# 6     20210311_대전광역시  2021-03-11 00:00:00   대전    1952.0        0.0
# 7     20210311_부산광역시  2021-03-11 00:00:00   부산    3311.0        0.0
# 8     20210311_서울특별시  2021-03-11 00:00:00   서울   12595.0        0.0
# ...              ...                  ...  ...       ...        ...
# 4870  20211206_광주광역시  2021-12-06 00:00:00   광주      16.0       22.0
# 4871  20211206_대구광역시  2021-12-06 00:00:00   대구      35.0       36.0
# 4872  20211206_대전광역시  2021-12-06 00:00:00   대전      40.0       28.0
# 4873  20211206_부산광역시  2021-12-06 00:00:00   부산      85.0       92.0
# 4874  20211206_서울특별시  2021-12-06 00:00:00   서울     346.0      400.0
#
#       totalFirstCnt  totalSecondCnt  accumulatedFirstCnt  \
# 4             22683             0.0                20280
# 5             25411             0.0                23101
# 6             14525             0.0                12573
# 7             40045             0.0                36734
# 8             73827             0.0                61232
# ...             ...             ...                  ...
# 4870        1191925       1148110.0              1191909
# 4871        1898227       1835971.0              1898192
# 4872        1175320       1136378.0              1175280
# 4873        2727591       2639817.0              2727506
# 4874        7945695       7723156.0              7945349
#
#       accumulatedSecondCnt        Time
# 4                      0.0  2021-03-11
# 5                      0.0  2021-03-11
# 6                      0.0  2021-03-11
# 7                      0.0  2021-03-11
# 8                      0.0  2021-03-11
# ...                    ...         ...
# 4870             1148088.0  2021-12-06
# 4871             1835935.0  2021-12-06
# 4872             1136350.0  2021-12-06
# 4873             2639725.0  2021-12-06
# 4874             7722756.0  2021-12-06
#
# [1355 rows x 10 columns]

# %%
vaccine_columns = ['Time', 'sido', 'totalFirstCnt', 'totalSecondCnt']
vaccine = vaccine[vaccine_columns]
vaccine
# Out:
#             Time sido  totalFirstCnt  totalSecondCnt
# 4     2021-03-11   광주          22683             0.0
# 5     2021-03-11   대구          25411             0.0
# 6     2021-03-11   대전          14525             0.0
# 7     2021-03-11   부산          40045             0.0
# 8     2021-03-11   서울          73827             0.0
# ...          ...  ...            ...             ...
# 4870  2021-12-06   광주        1191925       1148110.0
# 4871  2021-12-06   대구        1898227       1835971.0
# 4872  2021-12-06   대전        1175320       1136378.0
# 4873  2021-12-06   부산        2727591       2639817.0
# 4874  2021-12-06   서울        7945695       7723156.0
#
# [1355 rows x 4 columns]

# %%
vaccine.rename(columns = {"Time": "Time", "sido": "Location", 'totalFirstCnt' : 'totalFirstCnt', 'totalSecondCnt' : 'totalSecondCnt'}, inplace=True)
vaccine
# Out:
#             Time Location  totalFirstCnt  totalSecondCnt
# 4     2021-03-11       광주          22683             0.0
# 5     2021-03-11       대구          25411             0.0
# 6     2021-03-11       대전          14525             0.0
# 7     2021-03-11       부산          40045             0.0
# 8     2021-03-11       서울          73827             0.0
# ...          ...      ...            ...             ...
# 4870  2021-12-06       광주        1191925       1148110.0
# 4871  2021-12-06       대구        1898227       1835971.0
# 4872  2021-12-06       대전        1175320       1136378.0
# 4873  2021-12-06       부산        2727591       2639817.0
# 4874  2021-12-06       서울        7945695       7723156.0
#
# [1355 rows x 4 columns]

# %%
vaccine['TL'] = vaccine.Time + '_' + vaccine.Location
vaccine
# Out:
#             Time Location  totalFirstCnt  totalSecondCnt             TL
# 4     2021-03-11       광주          22683             0.0  2021-03-11_광주
# 5     2021-03-11       대구          25411             0.0  2021-03-11_대구
# 6     2021-03-11       대전          14525             0.0  2021-03-11_대전
# 7     2021-03-11       부산          40045             0.0  2021-03-11_부산
# 8     2021-03-11       서울          73827             0.0  2021-03-11_서울
# ...          ...      ...            ...             ...            ...
# 4870  2021-12-06       광주        1191925       1148110.0  2021-12-06_광주
# 4871  2021-12-06       대구        1898227       1835971.0  2021-12-06_대구
# 4872  2021-12-06       대전        1175320       1136378.0  2021-12-06_대전
# 4873  2021-12-06       부산        2727591       2639817.0  2021-12-06_부산
# 4874  2021-12-06       서울        7945695       7723156.0  2021-12-06_서울
#
# [1355 rows x 5 columns]

# %%
vaccine = vaccine.sort_values(by='TL' ,ascending=True)
vaccine
# Out:
#             Time Location  totalFirstCnt  totalSecondCnt             TL
# 4     2021-03-11       광주          22683             0.0  2021-03-11_광주
# 5     2021-03-11       대구          25411             0.0  2021-03-11_대구
# 6     2021-03-11       대전          14525             0.0  2021-03-11_대전
# 7     2021-03-11       부산          40045             0.0  2021-03-11_부산
# 8     2021-03-11       서울          73827             0.0  2021-03-11_서울
# ...          ...      ...            ...             ...            ...
# 4870  2021-12-06       광주        1191925       1148110.0  2021-12-06_광주
# 4871  2021-12-06       대구        1898227       1835971.0  2021-12-06_대구
# 4872  2021-12-06       대전        1175320       1136378.0  2021-12-06_대전
# 4873  2021-12-06       부산        2727591       2639817.0  2021-12-06_부산
# 4874  2021-12-06       서울        7945695       7723156.0  2021-12-06_서울
#
# [1355 rows x 5 columns]

# %%
su = pd.read_csv('./data/corona/SUBU_2020.csv')
su['년월일'] = pd.to_datetime(su['년월일'], format=('%Y%m%d'))

# %%
su21 = pd.read_csv('./data/corona/SUBU_2021.csv')
su21['년월일'] = pd.to_datetime(su21['년월일'], format=('%Y-%m-%d'))

# %%
susu = pd.concat([su,su21],join='outer')
susu_columns = ['년월일', '합계']
susu = susu[susu_columns]
su1 = susu.groupby('년월일').sum()

# %%
su1.to_csv('./data/corona/SUBU.csv')
subu = pd.read_csv('./data/corona/SUBU.csv')
subu['지역'] = '부산'
subu.rename(columns = {"년월일": "Time", "지역": "Location", '합계' : '지하철이용량'}, inplace=True)

# %%
subu['Time'] = subu['Time'].astype(str)
subu['TL'] = subu.Time + '_' + subu.Location
subu
# Out:
#            Time   지하철이용량 Location             TL
# 0    2020-01-01  1141775       부산  2020-01-01_부산
# 1    2020-01-02  1965828       부산  2020-01-02_부산
# 2    2020-01-03  2070347       부산  2020-01-03_부산
# 3    2020-01-04  1689211       부산  2020-01-04_부산
# 4    2020-01-05  1230476       부산  2020-01-05_부산
# ..          ...      ...      ...            ...
# 695  2021-11-26  1815977       부산  2021-11-26_부산
# 696  2021-11-27  1437714       부산  2021-11-27_부산
# 697  2021-11-28  1014197       부산  2021-11-28_부산
# 698  2021-11-29  1700912       부산  2021-11-29_부산
# 699  2021-11-30  1483806       부산  2021-11-30_부산
#
# [700 rows x 4 columns]

# %%
su = pd.read_csv('./data/corona/SUSE_2020.csv')
su['날짜'] = pd.to_datetime(su['날짜'], format=('%Y-%m-%d'))
su['지하철이용량'] = su['06:00 이전'] + su['06:00 ~ 07:00'] + su['07:00 ~ 08:00'] + su['08:00 ~ 09:00'] + su['09:00 ~ 10:00'] + su['10:00 ~ 11:00'] + su['11:00 ~ 12:00'] + su['12:00 ~ 13:00'] + su['13:00 ~ 14:00'] + su['14:00 ~ 15:00'] + su['15:00 ~ 16:00'] + su['16:00 ~ 17:00'] + su['17:00 ~ 18:00'] + su['18:00 ~ 19:00'] + su['19:00 ~ 20:00'] + su['20:00 ~ 21:00'] + su['21:00 ~ 22:00'] + su['22:00 ~ 23:00'] + su['23:00 ~ 24:00'] + su['24:00 이후']
su
# Out:
#                날짜   호선   역번호   역명  구분  06:00 이전  06:00 ~ 07:00  07:00 ~ 08:00  \
# 0      2020-01-01  1호선   150  서울역  승차       356            280            313
# 1      2020-01-01  1호선   150  서울역  하차       235            952            828
# 2      2020-01-01  1호선   151   시청  승차       105            118            123
# 3      2020-01-01  1호선   151   시청  하차        81            223            334
# 4      2020-01-01  1호선   152   종각  승차       798            366            198
# ...           ...  ...   ...  ...  ..       ...            ...            ...
# 202275 2020-12-31  8호선  2825   신흥  하차        31             95             78
# 202276 2020-12-31  8호선  2826   수진  승차       112            203            475
# 202277 2020-12-31  8호선  2826   수진  하차        15             70             92
# 202278 2020-12-31  8호선  2827   모란  승차        49             88            246
# 202279 2020-12-31  8호선  2827   모란  하차        15             59            111
#
#         08:00 ~ 09:00  09:00 ~ 10:00  ...  16:00 ~ 17:00  17:00 ~ 18:00  \
# 0                 774            923  ...           3194           3342
# 1                1043           1694  ...           2354           2261
# 2                 206            318  ...           1019           1234
# 3                 570            611  ...            783            849
# 4                 236            310  ...           1748           1890
# ...               ...            ...  ...            ...            ...
# 202275            211            145  ...            341            381
# 202276            641            311  ...            236            226
# 202277            227            190  ...            309            300
# 202278            314            176  ...            234            261
# 202279            181            142  ...            183            228
#
#         18:00 ~ 19:00  19:00 ~ 20:00  20:00 ~ 21:00  21:00 ~ 22:00  \
# 0                3002           2857           2311           2523
# 1                1922           1696           1620           1181
# 2                1383           1271           1061            991
# 3                 602            435            293            273
# 4                1879           1827           1955           1800
# ...               ...            ...            ...            ...
# 202275            428            292            229            219
# 202276            223            121             90            109
# 202277            372            296            232            202
# 202278            282            140             86            112
# 202279            183            162             71             99
#
#         22:00 ~ 23:00  23:00 ~ 24:00  24:00 이후  지하철이용량
# 0                1830            987        25   36641
# 1                 768            426        77   30085
# 2                 572            217         2   12212
# 3                 174            149        26   10608
# 4                1259            406         6   20523
# ...               ...            ...       ...     ...
# 202275             85             42         0    3920
# 202276             35             19         0    4053
# 202277            127             45         0    3754
# 202278             45              6         0    3223
# 202279             39             25         3    2405
#
# [202280 rows x 26 columns]

# %%
su21 = pd.read_csv('./data/corona/SUSE_2021.csv')
su21['날짜'] = pd.to_datetime(su21['날짜'], format=('%Y-%m-%d'))
su21['지하철이용량'] = su21['6시이전'] + su21['6시-7시'] + su21['7시-8시'] + su21['8시-9시'] + su21['9시-10시'] + su21['10시-11시'] + su21['11시-12시'] + su21['12시-13시'] + su21['13시-14시'] + su21['14시-15시'] + su21['15시-16시'] + su21['16시-17시'] + su21['17시-18시'] + su21['18시-19시'] + su21['19시-20시'] + su21['20시-21시'] + su21['21시-22시'] + su21['22시-23시'] + su21['23시이후']
su21
# Out:
#                날짜   호선   역번호   역명  구분  6시이전  6시-7시  7시-8시  8시-9시  9시-10시  ...  \
# 0      2021-01-01  1호선   150  서울역  승차    86    111    157    306     333  ...
# 1      2021-01-01  1호선   150  서울역  하차    85    355    438    592     841  ...
# 2      2021-01-01  1호선   151   시청  승차    43     45     75    111      95  ...
# 3      2021-01-01  1호선   151   시청  하차    40    145    176    312     223  ...
# 4      2021-01-01  1호선   152   종각  승차    49     59     89    126     125  ...
# ...           ...  ...   ...  ...  ..   ...    ...    ...    ...     ...  ...
# 135871 2021-08-31  8호선  2825   신흥  하차    24    125    126    284     162  ...
# 135872 2021-08-31  8호선  2826   수진  승차   144    247    624    839     352  ...
# 135873 2021-08-31  8호선  2826   수진  하차    26     80    120    408     164  ...
# 135874 2021-08-31  8호선  2827   모란  승차    67    126    344    441     247  ...
# 135875 2021-08-31  8호선  2827   모란  하차    29     99    140    331     161  ...
#
#         15시-16시  16시-17시  17시-18시  18시-19시  19시-20시  20시-21시  21시-22시  \
# 0           837      796      839      658      579      479      510
# 1           781      710      626      437      425      354      307
# 2           227      233      347      294      186      216      204
# 3           158      140      152      121       57       54       64
# 4           513      548      504      572      492      593      513
# ...         ...      ...      ...      ...      ...      ...      ...
# 135871      265      273      344      604      464      254      245
# 135872      178      307      282      244      124      112      109
# 135873      244      266      333      590      493      270      276
# 135874      216      292      277      348      154      128      120
# 135875      163      196      201      272      186       90      120
#
#         22시-23시  23시이후  지하철이용량
# 0           445    101    9339
# 1           134     77    9951
# 2           110     29    2947
# 3            23     17    2700
# 4           130     31    5686
# ...         ...    ...     ...
# 135871      152     53    4233
# 135872       60     15    4764
# 135873      192     73    4486
# 135874       72     10    3768
# 135875       61     29    2822
#
# [135876 rows x 25 columns]

# %%
su9 = pd.read_csv('./data/corona/SUSE_2021_09.csv')
su9['사용일자'] = su9.index
su9['사용일자'] = pd.to_datetime(su9['사용일자'], format=('%Y%m%d'))
su9 = su9.reset_index()
su9['지하철이용량'] = su9['역명'] + su9['승차총승객수']
su9['날짜'] = su9['사용일자']
su9
# Out:
#           index       사용일자        노선명     역명  승차총승객수    하차총승객수  등록일자  지하철이용량  \
# 0      20210901 2021-09-01    동작(현충원)   1929    1999  20210904   NaN    3928
# 1      20210901 2021-09-01  총신대입구(이수)  17219   18876  20210904   NaN   36095
# 2      20210901 2021-09-01         사당  21027   17484  20210904   NaN   38511
# 3      20210901 2021-09-01        남태령   1089     986  20210904   NaN    2075
# 4      20210901 2021-09-01        당고개  11684   10696  20210904   NaN   22380
# ...         ...        ...        ...    ...     ...       ...   ...     ...
# 18043  20210930 2021-09-30        신논현  28562   28302  20211003   NaN   56864
# 18044  20210930 2021-09-30         언주   9859   10044  20211003   NaN   19903
# 18045  20210930 2021-09-30        선정릉   9308   10135  20211003   NaN   19443
# 18046  20210930 2021-09-30       삼성중앙   6389    6552  20211003   NaN   12941
# 18047  20210930 2021-09-30        봉은사  14768   15040  20211003   NaN   29808
#
#               날짜
# 0     2021-09-01
# 1     2021-09-01
# 2     2021-09-01
# 3     2021-09-01
# 4     2021-09-01
# ...          ...
# 18043 2021-09-30
# 18044 2021-09-30
# 18045 2021-09-30
# 18046 2021-09-30
# 18047 2021-09-30
#
# [18048 rows x 9 columns]

# %%
su10 = pd.read_csv('./data/corona/SUSE_2021_10.csv')
su10['사용일자'] = su10.index
su10['사용일자'] = pd.to_datetime(su10['사용일자'], format=('%Y%m%d'))
su10 = su10.reset_index()
su10['지하철이용량'] = su10['역명'] + su10['승차총승객수']
su10['날짜'] = su10['사용일자']
su10
# Out:
#           index       사용일자           노선명     역명  승차총승객수    하차총승객수  등록일자  \
# 0      20211001 2021-10-01            용문   1971    2116  20211004   NaN
# 1      20211001 2021-10-01            지평     64      99  20211004   NaN
# 2      20211001 2021-10-01          수원시청  12282   13553  20211004   NaN
# 3      20211001 2021-10-01          매탄권선   4946    4770  20211004   NaN
# 4      20211001 2021-10-01            망포  14495   13274  20211004   NaN
# ...         ...        ...           ...    ...     ...       ...   ...
# 18635  20211031 2021-10-31            원흥   5341    5168  20211103   NaN
# 18636  20211031 2021-10-31            삼송  11019   10617  20211103   NaN
# 18637  20211031 2021-10-31  청량리(서울시립대입구)  13011   13412  20211103   NaN
# 18638  20211031 2021-10-31           제기동   9959   10367  20211103   NaN
# 18639  20211031 2021-10-31           신설동   7677    7353  20211103   NaN
#
#        지하철이용량         날짜
# 0        4087 2021-10-01
# 1         163 2021-10-01
# 2       25835 2021-10-01
# 3        9716 2021-10-01
# 4       27769 2021-10-01
# ...       ...        ...
# 18635   10509 2021-10-31
# 18636   21636 2021-10-31
# 18637   26423 2021-10-31
# 18638   20326 2021-10-31
# 18639   15030 2021-10-31
#
# [18640 rows x 9 columns]

# %%
su11 = pd.read_csv('./data/corona/SUSE_2021_11.csv')
su11['사용일자'] = su11.index
su11['사용일자'] = pd.to_datetime(su11['사용일자'], format=('%Y%m%d'))
su11 = su11.reset_index()
su11['지하철이용량'] = su11['역명'] + su11['승차총승객수']
su11['날짜'] = su11['사용일자']
su11
# Out:
#           index       사용일자           노선명     역명  승차총승객수    하차총승객수  등록일자  \
# 0      20211101 2021-11-01           동대문  10855   10327  20211104   NaN
# 1      20211101 2021-11-01           신설동  13933   13614  20211104   NaN
# 2      20211101 2021-11-01           제기동  17584   17948  20211104   NaN
# 3      20211101 2021-11-01  청량리(서울시립대입구)  19604   19787  20211104   NaN
# 4      20211101 2021-11-01            시청  23006   22704  20211104   NaN
# ...         ...        ...           ...    ...     ...       ...   ...
# 16871  20211129 2021-11-29            지축      1       0  20211202   NaN
# 16872  20211129 2021-11-29            삼송  19309   18605  20211202   NaN
# 16873  20211129 2021-11-29            원당  11314   10607  20211202   NaN
# 16874  20211129 2021-11-29            화정  17010   17285  20211202   NaN
# 16875  20211129 2021-11-29            영종   2969    2934  20211202   NaN
#
#        지하철이용량         날짜
# 0       21182 2021-11-01
# 1       27547 2021-11-01
# 2       35532 2021-11-01
# 3       39391 2021-11-01
# 4       45710 2021-11-01
# ...       ...        ...
# 16871       1 2021-11-29
# 16872   37914 2021-11-29
# 16873   21921 2021-11-29
# 16874   34295 2021-11-29
# 16875    5903 2021-11-29
#
# [16876 rows x 9 columns]

# %%
susu = pd.concat([su,su21],join='outer')
susu = pd.concat([susu,su9],join='outer')
susu = pd.concat([susu,su10],join='outer')
susu = pd.concat([susu,su11],join='outer')
susu_columns = ['날짜', '지하철이용량']
susu = susu[susu_columns]
su1 = susu.groupby('날짜').sum()
su1
# Out:
#               지하철이용량
# 날짜
# 2020-01-01   4375264
# 2020-01-02  10157852
# 2020-01-03  10846500
# 2020-01-04   7752350
# 2020-01-05   5518080
# ...              ...
# 2021-11-25  13856357
# 2021-11-26  14234887
# 2021-11-27  10046097
# 2021-11-28   7309283
# 2021-11-29  13407624
#
# [698 rows x 1 columns]

# %%
su1.to_csv('./data/corona/SUSE.csv')
suse = pd.read_csv('./data/corona/SUSE.csv')
suse['지역'] = '서울'
suse.rename(columns = {"날짜": "Time", "지역": "Location", '지하철이용량' : '지하철이용량'}, inplace=True)

# %%
suse['Time'] = suse['Time'].astype(str)
suse['TL'] = suse.Time + '_' + suse.Location
suse
# Out:
#            Time    지하철이용량 Location             TL
# 0    2020-01-01   4375264       서울  2020-01-01_서울
# 1    2020-01-02  10157852       서울  2020-01-02_서울
# 2    2020-01-03  10846500       서울  2020-01-03_서울
# 3    2020-01-04   7752350       서울  2020-01-04_서울
# 4    2020-01-05   5518080       서울  2020-01-05_서울
# ..          ...       ...      ...            ...
# 693  2021-11-25  13856357       서울  2021-11-25_서울
# 694  2021-11-26  14234887       서울  2021-11-26_서울
# 695  2021-11-27  10046097       서울  2021-11-27_서울
# 696  2021-11-28   7309283       서울  2021-11-28_서울
# 697  2021-11-29  13407624       서울  2021-11-29_서울
#
# [698 rows x 4 columns]

# %%
su = pd.read_csv('./data/corona/SUDA_2020.csv')
def day_convert(x):
    if x <10:
        x = '0' + str(x)
    return x
su['월'] = su['월'].apply(day_convert)
su['일'] = su['일'].apply(day_convert)
su['월'] = su['월'].astype(str)
su['일'] = su['일'].astype(str)
su['날짜'] = '2020' + su['월'] + su['일']
su['날짜'] = pd.to_datetime(su['날짜'], format=('%Y%m%d'))
su
# Out:
#         월   일   역번호    역명  승하  05~06  06~07  07~08  08~09  09~10  ...  16~17  \
# 0      01  01  1150  설화명곡  승차     45     55     81    128    152  ...    226
# 1      01  01  1150  설화명곡  하차      3    114     63     70     85  ...    192
# 2      01  01  1160    화원  승차     29     41     45     95    158  ...    220
# 3      01  01  1160    화원  하차      1     80     52     62     89  ...    240
# 4      01  01  1170    대곡  승차     44     80     97    152    222  ...    301
# ...    ..  ..   ...   ...  ..    ...    ...    ...    ...    ...  ...    ...
# 66607  12  31  3390    지산  하차      1     27     14     86     43  ...    109
# 66608  12  31  3400    범물  승차     33     65    217    286    178  ...    181
# 66609  12  31  3400    범물  하차      3     26     34    164    142  ...    306
# 66610  12  31  3410    용지  승차     23     41    118    146    120  ...     85
# 66611  12  31  3410    용지  하차      2     14     35    136     66  ...    142
#
#        17~18  18~19  19~20  20~21  21~22  22~23  23~24    일계         날짜
# 0        208    201    109     94     64     38      4  2855 2020-01-01
# 1        245    242    188    189    197    145    111  2697 2020-01-01
# 2        181    152     83     97     60     38     10  2626 2020-01-01
# 3        230    227    179    104    146    102     82  2753 2020-01-01
# 4        300    223    168     96    119     64     22  3933 2020-01-01
# ...      ...    ...    ...    ...    ...    ...    ...   ...        ...
# 66607    149    181     99     67     69     44     27  1394 2020-12-31
# 66608    202    175     85     85     71     34     12  2911 2020-12-31
# 66609    267    289    198    109    129     67     47  2821 2020-12-31
# 66610     66     98     34     31     23     28      6  1526 2020-12-31
# 66611    134    128     77     63     63     34     27  1469 2020-12-31
#
# [66612 rows x 26 columns]

# %%
su21 = pd.read_csv('./data/corona/SUDA_2021.csv')
def day_convert(x):
    if x <10:
        x = '0' + str(x)
    return x
su21['월'] = su21['월'].apply(day_convert)
su21['일'] = su21['일'].apply(day_convert)
su21['월'] = su21['월'].astype(str)
su21['일'] = su21['일'].astype(str)
su21['날짜'] = '2021' + su21['월'] + su21['일']
su21['날짜'] = pd.to_datetime(su21['날짜'], format=('%Y%m%d'))
su21
# Out:
#         월   일   역번호    역명  승하  05시-06시  06시-07시  07시-08시  08시-09시  09시-10시  \
# 0      01  01  1150  설화명곡  승차       26       25       42       57       68
# 1      01  01  1150  설화명곡  하차        4       32       43       47       45
# 2      01  01  1160    화원  승차       13       16       34       75       78
# 3      01  01  1160    화원  하차        2       20       18       56       67
# 4      01  01  1170    대곡  승차       31       52       64      107      120
# ...    ..  ..   ...   ...  ..      ...      ...      ...      ...      ...
# 60783  11  30  3390    지산  하차        4       31       28       46       71
# 60784  11  30  3400    범물  승차       59       68      110      194      214
# 60785  11  30  3400    범물  하차        2       27       65      116      180
# 60786  11  30  3410    용지  승차       47       72       60      106      140
# 60787  11  30  3410    용지  하차        1       32       50      101       85
#
#        ...  16시-17시  17시-18시  18시-19시  19시-20시  20시-21시  21시-22시  22시-23시  \
# 0      ...      104      119       81       65       46       37       24
# 1      ...       93      118      126       81       80       98       70
# 2      ...      187      150       76       47       41       37       23
# 3      ...      154      131      105       77       96      122       57
# 4      ...      191      180      117       63       82       48       40
# ...    ...      ...      ...      ...      ...      ...      ...      ...
# 60783  ...      164      202      137       96       93       73       50
# 60784  ...      228      219      180       87       79       72       43
# 60785  ...      300      263      244      131      132      121      111
# 60786  ...      132      107       70       55       29       23       29
# 60787  ...      136      163      106       80       79       49       41
#
#        23시-24시    일계         날짜
# 0            3  1387 2021-01-01
# 1           34  1364 2021-01-01
# 2            7  1746 2021-01-01
# 3           26  1773 2021-01-01
# 4           11  2171 2021-01-01
# ...        ...   ...        ...
# 60783       62  1686 2021-11-30
# 60784       15  3212 2021-11-30
# 60785       88  3047 2021-11-30
# 60786        3  1780 2021-11-30
# 60787       35  1710 2021-11-30
#
# [60788 rows x 26 columns]

# %%
susu = pd.concat([su,su21],join='outer')
susu_columns = ['날짜', '일계']
susu = susu[susu_columns]
su1 = susu.groupby('날짜').sum()
su1
# Out:
#                 일계
# 날짜
# 2020-01-01  492212
# 2020-01-02  928448
# 2020-01-03  986434
# 2020-01-04  835203
# 2020-01-05  621723
# ...            ...
# 2021-11-26  815452
# 2021-11-27  808559
# 2021-11-28  804807
# 2021-11-29  838465
# 2021-11-30  666315
#
# [700 rows x 1 columns]

# %%
su1.to_csv('./data/corona/SUDA.csv')
suda = pd.read_csv('./data/corona/SUDA.csv')
suda['지역'] = '대구'
suda.rename(columns = {"날짜": "Time", "지역": "Location", '일계' : '지하철이용량'}, inplace=True)

# %%
suda['Time'] = suda['Time'].astype(str)
suda['TL'] = suda.Time + '_' + suda.Location
suda
# Out:
#            Time  지하철이용량 Location             TL
# 0    2020-01-01  492212       대구  2020-01-01_대구
# 1    2020-01-02  928448       대구  2020-01-02_대구
# 2    2020-01-03  986434       대구  2020-01-03_대구
# 3    2020-01-04  835203       대구  2020-01-04_대구
# 4    2020-01-05  621723       대구  2020-01-05_대구
# ..          ...     ...      ...            ...
# 695  2021-11-26  815452       대구  2021-11-26_대구
# 696  2021-11-27  808559       대구  2021-11-27_대구
# 697  2021-11-28  804807       대구  2021-11-28_대구
# 698  2021-11-29  838465       대구  2021-11-29_대구
# 699  2021-11-30  666315       대구  2021-11-30_대구
#
# [700 rows x 4 columns]

# %%
su = pd.read_csv('./data/corona/SUGW_2020.csv')
su['일자'] = pd.to_datetime(su['일자'], format=('%Y-%m-%d'))

# %%
su_columns = ['01~05', '05~06', '06~07', '07~08', '08~09','09~10', '10~11', '11~12', '12~13', '13~14', '14~15', '15~16', '16~17','17~18', '18~19', '19~20', '20~21', '21~22', '22~23', '23~24', '24~01']
su['합계'] = 0
for i in su_columns:
    su['합계'] += su[i]
su
# Out:
#               일자  역번호      역명  구분  01~05  05~06  06~07  07~08  08~09  09~10  \
# 0     2020-01-01  100      녹동  승차      0      0      2      2      8      6
# 1     2020-01-01  100      녹동  하차      0      0      0      1      2      1
# 2     2020-01-01  101      소태  승차      0     21     13     53     46     86
# 3     2020-01-01  101      소태  하차      0      0     34     29     28     37
# 4     2020-01-01  102  학동증심사   승차      0     16     21     38     66     79
# ...          ...  ...     ...  ..    ...    ...    ...    ...    ...    ...
# 14635 2020-12-31  117    광주송정  하차      0     38    134    317    392    240
# 14636 2020-12-31  118      도산  승차      0     37     82    249    253    132
# 14637 2020-12-31  118      도산  하차      0      7     34     95    128     41
# 14638 2020-12-31  119      평동  승차      0     16     39     56     83     37
# 14639 2020-12-31  119      평동  하차      0     32    213    861    445     94
#
#        ...  16~17  17~18  18~19  19~20  20~21  21~22  22~23  23~24  24~01  \
# 0      ...      7      3      6      0      2     23      0      0      0
# 1      ...      5      5      5      2      4     27      2      0      0
# 2      ...     90     87     52     42     42     32      9      3      0
# 3      ...     77     78     79     60     54     56     37     22      5
# 4      ...    111     85     59     53     45     18     20     14      2
# ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 14635  ...    273    421    477    295    261    116     70     41      0
# 14636  ...    128    153    129     44     31     28     17      9      0
# 14637  ...    129    163    208    104     73     64     62     21      1
# 14638  ...    306    513    219     96     40     29     25      9      0
# 14639  ...     54     71     48     43     38     26     12      7      0
#
#          합계
# 0        83
# 1        78
# 2      1036
# 3       922
# 4      1273
# ...     ...
# 14635  4492
# 14636  1800
# 14637  1497
# 14638  2080
# 14639  2218
#
# [14640 rows x 26 columns]

# %%
su21 = pd.read_csv('./data/corona/SUGW_2021.csv')
su21['일자'] = pd.to_datetime(su21['일자'], format=('%Y-%m-%d'))

# %%
su_columns = ['05_06', '06_07', '07_08', '08_09', '09_10','10_11', '11_12', '12_13', '13_14', '14_15', '15_16', '16_17', '17_18','18_19', '19_20', '20_21', '21_22', '22_23', '23_24']
su21['합계'] = 0
for i in su_columns:
    su21['합계'] += su21[i]
su21
# Out:
#               일자  역번호      역명  구분  05_06  06_07  07_08  08_09  09_10  10_11  \
# 0     2021-01-01  100      녹동  승차      0      0      1      6      5      2
# 1     2021-01-01  100      녹동  하차      0      0      3      1      1      1
# 2     2021-01-01  101      소태  승차     10     15     45     33     38     56
# 3     2021-01-01  101      소태  하차      2     15     30     30     30     42
# 4     2021-01-01  102  학동증심사   승차     14     10     32     34     41     40
# ...          ...  ...     ...  ..    ...    ...    ...    ...    ...    ...
# 13355 2021-11-30  117    광주송정  하차     42     82    290    334    173    204
# 13356 2021-11-30  118      도산  승차     28     56    254    267    104     65
# 13357 2021-11-30  118      도산  하차      6     26     52     79     47     39
# 13358 2021-11-30  119      평동  승차     17     21     73     97     54     34
# 13359 2021-11-30  119      평동  하차     25    219    964    331     48     36
#
#        ...  15_16  16_17  17_18  18_19  19_20  20_21  21_22  22_23  23_24  \
# 0      ...      5      2      1      3      2      3      2      2      0
# 1      ...      3      2      2      1      2      3     18      3      0
# 2      ...     55     47     40     36     16     13     14      5      1
# 3      ...     48     52     62     51     36     21     32      8      8
# 4      ...     73     97     67     64     36     17     12     11     12
# ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 13355  ...    163    243    328    309    155    110     78     75     22
# 13356  ...     62     58    133    119     49     28     40     17     17
# 13357  ...     99     94    174    184     87     45     72     73     30
# 13358  ...     91    178    560    273    273    134     53     23      9
# 13359  ...     45     51     65     77     81     11     22     13     12
#
#          합계
# 0        49
# 1        48
# 2       617
# 3       636
# 4       842
# ...     ...
# 13355  3289
# 13356  1571
# 13357  1339
# 13358  2105
# 13359  2176
#
# [13360 rows x 24 columns]

# %%
susu = pd.concat([su,su21],join='outer')
susu_columns = ['일자', '합계']
susu = susu[susu_columns]
su1 = susu.groupby('일자').sum()

# %%
su1.to_csv('./data/corona/SUGW.csv')
sugw = pd.read_csv('./data/corona/SUGW.csv')
sugw['지역'] = '광주'
sugw.rename(columns = {"일자": "Time", "지역": "Location", '합계' : '지하철이용량'}, inplace=True)

# %%
sugw['Time'] = sugw['Time'].astype(str)
sugw['TL'] = sugw.Time + '_' + sugw.Location
sugw
# Out:
#            Time  지하철이용량 Location             TL
# 0    2020-01-01   56616       광주  2020-01-01_광주
# 1    2020-01-02  108528       광주  2020-01-02_광주
# 2    2020-01-03  116496       광주  2020-01-03_광주
# 3    2020-01-04   86399       광주  2020-01-04_광주
# 4    2020-01-05   60903       광주  2020-01-05_광주
# ..          ...     ...      ...            ...
# 695  2021-11-26  105545       광주  2021-11-26_광주
# 696  2021-11-27   73892       광주  2021-11-27_광주
# 697  2021-11-28   53367       광주  2021-11-28_광주
# 698  2021-11-29   98252       광주  2021-11-29_광주
# 699  2021-11-30   85844       광주  2021-11-30_광주
#
# [700 rows x 4 columns]

# %%
su = pd.read_csv('./data/corona/SUJU_2020.csv')
su['날짜'] = pd.to_datetime(su['날짜'], format=('%Y-%m-%d'))

# %%
su_columns = ['03_04시', '04_05시', '05_06시', '06_07시','07_08시', '08_09시', '09_10시', '10_11시', '11_12시', '12_13시', '13_14시','14_15시', '15_16시', '16_17시', '17_18시', '18_19시', '19_20시', '20_21시','21_22시', '22_23시', '23_00시', '00_01시', '01_02시', '02_03시']
su['합계'] = 0
for i in su_columns:
    su['합계'] += su[i]
su
# Out:
#               날짜   역번호  역명  구분  03_04시  04_05시  05_06시  06_07시  07_08시  \
# 0     2020-01-01  1101  판암  승차       0       0      40      41      68
# 1     2020-01-01  1101  판암  하차       0       0      16      72      49
# 2     2020-01-01  1102  신흥  승차       0       1      30      26      20
# 3     2020-01-01  1102  신흥  하차       0       0       5      20      27
# 4     2020-01-01  1103  대동  승차       0       0      39      40      50
# ...          ...   ...  ..  ..     ...     ...     ...     ...     ...
# 29475 2021-10-31  1120  노은  하차       0       0       4       5      21
# 29476 2021-10-31  1121  지족  승차       0       0       5      18      26
# 29477 2021-10-31  1121  지족  하차       0       0       8      18      16
# 29478 2021-10-31  1122  반석  승차       0       0      21      48      91
# 29479 2021-10-31  1122  반석  하차       0       0      22      32      70
#
#        08_09시  ...  18_19시  19_20시  20_21시  21_22시  22_23시  23_00시  00_01시  \
# 0         127  ...     122      93      79      41      35      16       0
# 1          63  ...     143     148     120     132     118      60      11
# 2          56  ...      67      32      31      17      12       6       0
# 3          27  ...      77      73      46      52      38      29       2
# 4         107  ...     164     109      91      73      56      34       0
# ...       ...  ...     ...     ...     ...     ...     ...     ...     ...
# 29475      41  ...     214     163     124     100      69      46       8
# 29476      41  ...      70      39      29      34      15      11       0
# 29477      41  ...      71      75      74      74      62      65       5
# 29478     158  ...     208     123     129     137      92      39       0
# 29479     112  ...     306     250     197     202     184      71      27
#
#        01_02시  02_03시    합계
# 0           0       0  2234
# 1           0       0  2143
# 2           0       0  1004
# 3           0       0   913
# 4           0       0  2187
# ...       ...     ...   ...
# 29475       0       0  2057
# 29476       0       0   981
# 29477       0       0  1005
# 29478       0       0  3390
# 29479       0       0  3365
#
# [29480 rows x 29 columns]

# %%
su21 = pd.read_csv('./data/corona/SUJU_2021.csv')
su21['날짜'] = pd.to_datetime(su21['날짜'], format=('%Y-%m-%d'))

# %%
su_columns = ['03_04시', '04_05시', '05_06시', '06_07시','07_08시', '08_09시', '09_10시', '10_11시', '11_12시', '12_13시', '13_14시','14_15시', '15_16시', '16_17시', '17_18시', '18_19시', '19_20시', '20_21시','21_22시', '22_23시', '23_00시', '00_01시', '01_02시', '02_03시']
su21['합계'] = 0
for i in su_columns:
    su21['합계'] += su21[i]
su21
# Out:
#               날짜   역번호  역명  구분  03_04시  04_05시  05_06시  06_07시  07_08시  \
# 0     2020-01-01  1101  판암  승차       0       0      40      41      68
# 1     2020-01-01  1101  판암  하차       0       0      16      72      49
# 2     2020-01-01  1102  신흥  승차       0       1      30      26      20
# 3     2020-01-01  1102  신흥  하차       0       0       5      20      27
# 4     2020-01-01  1103  대동  승차       0       0      39      40      50
# ...          ...   ...  ..  ..     ...     ...     ...     ...     ...
# 30795 2021-11-30  1120  노은  하차       0       0      19      30     184
# 30796 2021-11-30  1121  지족  승차       0       0      20      42     146
# 30797 2021-11-30  1121  지족  하차       0       0       7      31      89
# 30798 2021-11-30  1122  반석  승차       0       0      43     143     670
# 30799 2021-11-30  1122  반석  하차       0       0      41     143     385
#
#        08_09시  ...  18_19시  19_20시  20_21시  21_22시  22_23시  23_00시  00_01시  \
# 0         127  ...     122      93      79      41      35      16       0
# 1          63  ...     143     148     120     132     118      60      11
# 2          56  ...      67      32      31      17      12       6       0
# 3          27  ...      77      73      46      52      38      29       2
# 4         107  ...     164     109      91      73      56      34       0
# ...       ...  ...     ...     ...     ...     ...     ...     ...     ...
# 30795     293  ...     552     254     157     172     128      53       2
# 30796     237  ...     259      85      64      40      26      18       0
# 30797     308  ...     196      99      72      76      73      28       6
# 30798    1120  ...     739     292     223     233     190      69       0
# 30799     733  ...     992     388     270     322     291      85      30
#
#        01_02시  02_03시    합계
# 0           0       0  2234
# 1           0       0  2143
# 2           0       0  1004
# 3           0       0   913
# 4           0       0  2187
# ...       ...     ...   ...
# 30795       0       0  3697
# 30796       0       0  1816
# 30797       0       0  1706
# 30798       0       0  6699
# 30799       0       0  6280
#
# [30800 rows x 29 columns]

# %%
susu = pd.concat([su,su21],join='outer')
susu_columns = ['날짜', '합계']
susu = susu[susu_columns]
su1 = susu.groupby('날짜').sum()

# %%
su1.to_csv('./data/corona/SUJU.csv')
suju = pd.read_csv('./data/corona/SUJU.csv')
suju['지역'] = '대전'
suju.rename(columns = {"날짜": "Time", "지역": "Location", '합계' : '지하철이용량'}, inplace=True)

# %%
suju['Time'] = suju['Time'].astype(str)
suju['TL'] = suju.Time + '_' + suju.Location
suju
# Out:
#            Time  지하철이용량 Location             TL
# 0    2020-01-01  218720       대전  2020-01-01_대전
# 1    2020-01-02  456376       대전  2020-01-02_대전
# 2    2020-01-03  497312       대전  2020-01-03_대전
# 3    2020-01-04  365614       대전  2020-01-04_대전
# 4    2020-01-05  273340       대전  2020-01-05_대전
# ..          ...     ...      ...            ...
# 695  2021-11-26  204722       대전  2021-11-26_대전
# 696  2021-11-27  142761       대전  2021-11-27_대전
# 697  2021-11-28  100614       대전  2021-11-28_대전
# 698  2021-11-29  188336       대전  2021-11-29_대전
# 699  2021-11-30  167680       대전  2021-11-30_대전
#
# [700 rows x 4 columns]

# %%
suall_1 = pd.concat([subu,suse],join='outer')
suall_2 = pd.concat([suall_1,suda],join='outer')
suall_3 = pd.concat([suall_2,sugw],join='outer')
su_all = pd.concat([suall_3,suju],join='outer')

# %%
su_all = su_all.sort_values(by='TL' ,ascending=True)
su_all
# Out:
#            Time    지하철이용량 Location             TL
# 0    2020-01-01     56616       광주  2020-01-01_광주
# 0    2020-01-01    492212       대구  2020-01-01_대구
# 0    2020-01-01    218720       대전  2020-01-01_대전
# 0    2020-01-01   1141775       부산  2020-01-01_부산
# 0    2020-01-01   4375264       서울  2020-01-01_서울
# ..          ...       ...      ...            ...
# 697  2021-11-29  13407624       서울  2021-11-29_서울
# 699  2021-11-30     85844       광주  2021-11-30_광주
# 699  2021-11-30    666315       대구  2021-11-30_대구
# 699  2021-11-30    167680       대전  2021-11-30_대전
# 699  2021-11-30   1483806       부산  2021-11-30_부산
#
# [3498 rows x 4 columns]

# %%
all_corona = pd.merge(tall4, vaccine, on="TL", how="outer")
all_corona['totalFirstCnt'] = all_corona['totalFirstCnt'].fillna(0)
all_corona['totalSecondCnt'] = all_corona['totalSecondCnt'].fillna(0)

# %%
all_corona3 = pd.merge(all_corona, cosurv, on ='TL', how='outer')
all_corona3
# Out:
#           Time_x Location_x       총교통량             TL Time_y Location_y  \
# 0     2020-01-01         광주   163710.0  2020-01-01_광주    NaN        NaN
# 1     2020-01-01         대구   239039.0  2020-01-01_대구    NaN        NaN
# 2     2020-01-01         대전   160113.0  2020-01-01_대전    NaN        NaN
# 3     2020-01-01         부산   302030.0  2020-01-01_부산    NaN        NaN
# 4     2020-01-01         서울  1090782.0  2020-01-01_서울    NaN        NaN
# ...          ...        ...        ...            ...    ...        ...
# 3669         NaN        NaN        NaN  2020-10-01_서울    NaN        NaN
# 3670         NaN        NaN        NaN  2020-10-01_부산    NaN        NaN
# 3671         NaN        NaN        NaN  2020-10-01_대구    NaN        NaN
# 3672         NaN        NaN        NaN  2020-10-01_광주    NaN        NaN
# 3673         NaN        NaN        NaN  2020-10-01_대전    NaN        NaN
#
#       totalFirstCnt  totalSecondCnt Location  일일확진자        Time
# 0               0.0             0.0      NaN    NaN         NaN
# 1               0.0             0.0      NaN    NaN         NaN
# 2               0.0             0.0      NaN    NaN         NaN
# 3               0.0             0.0      NaN    NaN         NaN
# 4               0.0             0.0      NaN    NaN         NaN
# ...             ...             ...      ...    ...         ...
# 3669            NaN             NaN       서울   30.0  2020-10-01
# 3670            NaN             NaN       부산    6.0  2020-10-01
# 3671            NaN             NaN       대구    1.0  2020-10-01
# 3672            NaN             NaN       광주    3.0  2020-10-01
# 3673            NaN             NaN       대전    2.0  2020-10-01
#
# [3674 rows x 11 columns]

# %%
all_corona2 = pd.merge(all_corona3, su_all, on ='TL', how='outer')
all_corona2 = all_corona2.sort_values(by='TL' ,ascending=True)
all_corona2
# Out:
#           Time_x Location_x       총교통량             TL      Time_y Location_y  \
# 0     2020-01-01         광주   163710.0  2020-01-01_광주         NaN        NaN
# 1     2020-01-01         대구   239039.0  2020-01-01_대구         NaN        NaN
# 2     2020-01-01         대전   160113.0  2020-01-01_대전         NaN        NaN
# 3     2020-01-01         부산   302030.0  2020-01-01_부산         NaN        NaN
# 4     2020-01-01         서울  1090782.0  2020-01-01_서울         NaN        NaN
# ...          ...        ...        ...            ...         ...        ...
# 3664         NaN        NaN        NaN  2021-12-06_광주  2021-12-06         광주
# 3665         NaN        NaN        NaN  2021-12-06_대구  2021-12-06         대구
# 3666         NaN        NaN        NaN  2021-12-06_대전  2021-12-06         대전
# 3667         NaN        NaN        NaN  2021-12-06_부산  2021-12-06         부산
# 3668         NaN        NaN        NaN  2021-12-06_서울  2021-12-06         서울
#
#       totalFirstCnt  totalSecondCnt Location_x   일일확진자      Time_x  \
# 0               0.0             0.0        NaN     NaN         NaN
# 1               0.0             0.0        NaN     NaN         NaN
# 2               0.0             0.0        NaN     NaN         NaN
# 3               0.0             0.0        NaN     NaN         NaN
# 4               0.0             0.0        NaN     NaN         NaN
# ...             ...             ...        ...     ...         ...
# 3664      1191925.0       1148110.0         광주    43.0  2021-12-06
# 3665      1898227.0       1835971.0         대구   146.0  2021-12-06
# 3666      1175320.0       1136378.0         대전   106.0  2021-12-06
# 3667      2727591.0       2639817.0         부산   193.0  2021-12-06
# 3668      7945695.0       7723156.0         서울  1408.0  2021-12-06
#
#           Time_y     지하철이용량 Location_y
# 0     2020-01-01    56616.0         광주
# 1     2020-01-01   492212.0         대구
# 2     2020-01-01   218720.0         대전
# 3     2020-01-01  1141775.0         부산
# 4     2020-01-01  4375264.0         서울
# ...          ...        ...        ...
# 3664         NaN        NaN        NaN
# 3665         NaN        NaN        NaN
# 3666         NaN        NaN        NaN
# 3667         NaN        NaN        NaN
# 3668         NaN        NaN        NaN
#
# [3674 rows x 14 columns]

# %%
all_corona2 = all_corona2[all_corona2['일일확진자'].notnull()]
all_corona2 = all_corona2[all_corona2['totalFirstCnt'].notnull()]
all_corona2 = all_corona2[all_corona2['총교통량'].notnull()]
all_corona2 = all_corona2[all_corona2['지하철이용량'].notnull()]
corona_columns = ['TL', '일일확진자', '총교통량', 'totalFirstCnt', 'totalSecondCnt', '지하철이용량']
all_corona2 = all_corona2[corona_columns]
all_corona2
# Out:
#                  TL   일일확진자       총교통량  totalFirstCnt  totalSecondCnt  \
# 320   2020-03-05_광주     1.0   147404.0            0.0             0.0
# 321   2020-03-05_대구   321.0   227382.0            0.0             0.0
# 322   2020-03-05_대전     1.0   165456.0            0.0             0.0
# 324   2020-03-05_서울     4.0  1349015.0            0.0             0.0
# 325   2020-03-06_광주     1.0   167739.0            0.0             0.0
# ...             ...     ...        ...            ...             ...
# 3633  2021-11-29_서울  1389.0  1488677.0      7915339.0       7651555.0
# 3634  2021-11-30_광주    52.0   167934.0      1188227.0       1137390.0
# 3635  2021-11-30_대구    78.0   299925.0      1892769.0       1822081.0
# 3636  2021-11-30_대전    43.0   197423.0      1171479.0       1127617.0
# 3637  2021-11-30_부산    79.0   340303.0      2719676.0       2621647.0
#
#           지하철이용량
# 320      65372.0
# 321     260224.0
# 322     202762.0
# 324    6774786.0
# 325      71185.0
# ...          ...
# 3633  13407624.0
# 3634     85844.0
# 3635    666315.0
# 3636    167680.0
# 3637   1483806.0
#
# [3304 rows x 6 columns]

# %%
def tt_convert(data):
    a,b = str(data).split('_')
    return a
def ll_convert(data):
    a,b = str(data).split('_')
    return b
all_corona2['Time'] = all_corona2['TL'].apply(tt_convert)
all_corona2['Location'] = all_corona2['TL'].apply(ll_convert)
all_corona2
# Out:
#                  TL   일일확진자       총교통량  totalFirstCnt  totalSecondCnt  \
# 320   2020-03-05_광주     1.0   147404.0            0.0             0.0
# 321   2020-03-05_대구   321.0   227382.0            0.0             0.0
# 322   2020-03-05_대전     1.0   165456.0            0.0             0.0
# 324   2020-03-05_서울     4.0  1349015.0            0.0             0.0
# 325   2020-03-06_광주     1.0   167739.0            0.0             0.0
# ...             ...     ...        ...            ...             ...
# 3633  2021-11-29_서울  1389.0  1488677.0      7915339.0       7651555.0
# 3634  2021-11-30_광주    52.0   167934.0      1188227.0       1137390.0
# 3635  2021-11-30_대구    78.0   299925.0      1892769.0       1822081.0
# 3636  2021-11-30_대전    43.0   197423.0      1171479.0       1127617.0
# 3637  2021-11-30_부산    79.0   340303.0      2719676.0       2621647.0
#
#           지하철이용량        Time Location
# 320      65372.0  2020-03-05       광주
# 321     260224.0  2020-03-05       대구
# 322     202762.0  2020-03-05       대전
# 324    6774786.0  2020-03-05       서울
# 325      71185.0  2020-03-06       광주
# ...          ...         ...      ...
# 3633  13407624.0  2021-11-29       서울
# 3634     85844.0  2021-11-30       광주
# 3635    666315.0  2021-11-30       대구
# 3636    167680.0  2021-11-30       대전
# 3637   1483806.0  2021-11-30       부산
#
# [3304 rows x 8 columns]

# %%
all_corona2.head(10)
# Out:
#                 TL  일일확진자       총교통량  totalFirstCnt  totalSecondCnt  \
# 320  2020-03-05_광주    1.0   147404.0            0.0             0.0
# 321  2020-03-05_대구  321.0   227382.0            0.0             0.0
# 322  2020-03-05_대전    1.0   165456.0            0.0             0.0
# 324  2020-03-05_서울    4.0  1349015.0            0.0             0.0
# 325  2020-03-06_광주    1.0   167739.0            0.0             0.0
# 326  2020-03-06_대구  367.0   245297.0            0.0             0.0
# 327  2020-03-06_대전    2.0   187085.0            0.0             0.0
# 328  2020-03-06_부산    3.0   342056.0            0.0             0.0
# 329  2020-03-06_서울    2.0  1438802.0            0.0             0.0
# 330  2020-03-07_광주    1.0   136782.0            0.0             0.0
#
#         지하철이용량        Time Location
# 320    65372.0  2020-03-05       광주
# 321   260224.0  2020-03-05       대구
# 322   202762.0  2020-03-05       대전
# 324  6774786.0  2020-03-05       서울
# 325    71185.0  2020-03-06       광주
# 326   280312.0  2020-03-06       대구
# 327   222116.0  2020-03-06       대전
# 328  1016070.0  2020-03-06       부산
# 329  7002947.0  2020-03-06       서울
# 330    40470.0  2020-03-07       광주

# %%
df_columns = ['Time', '총교통량']
df2 = all_corona2[all_corona2['Location'] == '서울']
df2['Time'] = pd.to_datetime(df2['Time'], format=('%Y-%m-%d'))
df2 = df2[df_columns]
df2 = df2.set_index('Time')
df2
# Out:
#                  총교통량
# Time
# 2020-03-05  1349015.0
# 2020-03-06  1438802.0
# 2020-03-07  1196584.0
# 2020-03-08   965674.0
# 2020-03-09  1382670.0
# ...               ...
# 2021-11-25  1460843.0
# 2021-11-26  1554756.0
# 2021-11-27  1472830.0
# 2021-11-28  1326431.0
# 2021-11-29  1488677.0
#
# [661 rows x 1 columns]

# %%
df3_columns = ['Time', '일일확진자']
df3 = all_corona2[all_corona2['Location'] == '서울']
df3['Time'] = pd.to_datetime(df3['Time'], format=('%Y-%m-%d'))
df3 = df3[df3_columns]
df3 = df3.set_index('Time')
df3
# Out:
#              일일확진자
# Time
# 2020-03-05     4.0
# 2020-03-06     2.0
# 2020-03-07     3.0
# 2020-03-08    12.0
# 2020-03-09    10.0
# ...            ...
# 2021-11-25  1760.0
# 2021-11-26  1741.0
# 2021-11-27  1888.0
# 2021-11-28  1676.0
# 2021-11-29  1389.0
#
# [661 rows x 1 columns]

# %%
df4_columns = ['Time', '지하철이용량']
df4 = all_corona2[all_corona2['Location'] == '서울']
df4['Time'] = pd.to_datetime(df4['Time'], format=('%Y-%m-%d'))
df4 = df4[df4_columns]
df4 = df4.set_index('Time')
df4
# Out:
#                 지하철이용량
# Time
# 2020-03-05   6774786.0
# 2020-03-06   7002947.0
# 2020-03-07   3947455.0
# 2020-03-08   2729251.0
# 2020-03-09   7089676.0
# ...                ...
# 2021-11-25  13856357.0
# 2021-11-26  14234887.0
# 2021-11-27  10046097.0
# 2021-11-28   7309283.0
# 2021-11-29  13407624.0
#
# [661 rows x 1 columns]

# %%
import matplotlib.font_manager as fm
import matplotlib as mpl
mpl.rcParams['axes.unicode_minus'] = False

# %%
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = 'NanumGothicCoding'

# %%
df4['2021-10'].plot(title = 'Subway')
# Out:
# <AxesSubplot:title={'center':'Subway'}, xlabel='Time'>

# %%
df4['2021-11'].plot(title = 'Subway')
# Out:
# <AxesSubplot:title={'center':'Subway'}, xlabel='Time'>

# %%
df3['2021-10'].plot(title = 'Corona')
# Out:
# <AxesSubplot:title={'center':'Corona'}, xlabel='Time'>

# %%
df3['2021-11'].plot(title = 'Corona')
# Out:
# <AxesSubplot:title={'center':'Corona'}, xlabel='Time'>

# %%
all_corona_nova = all_corona2[all_corona2['totalFirstCnt'] == 0]
all_corona_nova
# Out:
#                  TL  일일확진자       총교통량  totalFirstCnt  totalSecondCnt  \
# 320   2020-03-05_광주    1.0   147404.0            0.0             0.0
# 321   2020-03-05_대구  321.0   227382.0            0.0             0.0
# 322   2020-03-05_대전    1.0   165456.0            0.0             0.0
# 324   2020-03-05_서울    4.0  1349015.0            0.0             0.0
# 325   2020-03-06_광주    1.0   167739.0            0.0             0.0
# ...             ...    ...        ...            ...             ...
# 2279  2021-03-10_광주    1.0   179593.0            0.0             0.0
# 2280  2021-03-10_대구    1.0    69181.0            0.0             0.0
# 2281  2021-03-10_대전    3.0   172645.0            0.0             0.0
# 2282  2021-03-10_부산    7.0   245531.0            0.0             0.0
# 2283  2021-03-10_서울  138.0  1053136.0            0.0             0.0
#
#          지하철이용량        Time Location
# 320     65372.0  2020-03-05       광주
# 321    260224.0  2020-03-05       대구
# 322    202762.0  2020-03-05       대전
# 324   6774786.0  2020-03-05       서울
# 325     71185.0  2020-03-06       광주
# ...         ...         ...      ...
# 2279    91553.0  2021-03-10       광주
# 2280   786368.0  2021-03-10       대구
# 2281   352352.0  2021-03-10       대전
# 2282  1619898.0  2021-03-10       부산
# 2283  8629615.0  2021-03-10       서울
#
# [1956 rows x 8 columns]

# %%
all_corona_va = all_corona2[all_corona2['totalFirstCnt'] != 0]
all_corona_va
# Out:
#                  TL   일일확진자       총교통량  totalFirstCnt  totalSecondCnt  \
# 2284  2021-03-11_광주     1.0   181109.0        22683.0             0.0
# 2285  2021-03-11_대구     4.0    70000.0        25411.0             0.0
# 2286  2021-03-11_대전     1.0   174447.0        14525.0             0.0
# 2287  2021-03-11_부산    14.0   248004.0        40045.0             0.0
# 2288  2021-03-11_서울   138.0  1065725.0        73827.0             0.0
# ...             ...     ...        ...            ...             ...
# 3633  2021-11-29_서울  1389.0  1488677.0      7915339.0       7651555.0
# 3634  2021-11-30_광주    52.0   167934.0      1188227.0       1137390.0
# 3635  2021-11-30_대구    78.0   299925.0      1892769.0       1822081.0
# 3636  2021-11-30_대전    43.0   197423.0      1171479.0       1127617.0
# 3637  2021-11-30_부산    79.0   340303.0      2719676.0       2621647.0
#
#           지하철이용량        Time Location
# 2284     89401.0  2021-03-11       광주
# 2285    781645.0  2021-03-11       대구
# 2286    353818.0  2021-03-11       대전
# 2287   1610695.0  2021-03-11       부산
# 2288   8543804.0  2021-03-11       서울
# ...          ...         ...      ...
# 3633  13407624.0  2021-11-29       서울
# 3634     85844.0  2021-11-30       광주
# 3635    666315.0  2021-11-30       대구
# 3636    167680.0  2021-11-30       대전
# 3637   1483806.0  2021-11-30       부산
#
# [1348 rows x 8 columns]

# %%
train_features = all_corona_va[['총교통량', 'totalSecondCnt', '지하철이용량']]
train_targets = all_corona_va['일일확진자']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(train_features, train_targets, test_size=0.2, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.linear_model import LogisticRegression

# %%
model = RandomForestClassifier(n_estimators=100,random_state=0,verbose=1)

model.fit(X_train, y_train)

# 예측
y_pred=model.predict(X_test)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    2.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished

# %%
from sklearn.metrics import mean_squared_error

# %%
print('RMSE : {:.6f}'.format(np.sqrt(mean_squared_error(y_val,y_pred))))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15688/2411596305.py in <module>
# ----> 1 print('RMSE : {:.6f}'.format(np.sqrt(mean_squared_error(y_val,y_pred))))
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\metrics\_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     436     0.825...
#     437     """
# --> 438     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     439         y_true, y_pred, multioutput
#     440     )
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\metrics\_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      92         the dtype argument passed to check_array.
#      93     """
# ---> 94     check_consistent_length(y_true, y_pred)
#      95     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      96     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     330     uniques = np.unique(lengths)
#     331     if len(uniques) > 1:
# --> 332         raise ValueError(
#     333             "Found input variables with inconsistent numbers of samples: %r"
#     334             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [216, 270]

# %%
resu_pi = pd.Series(model.feature_importances_,index=['Tallgate', 'totalSecondCnt', 'Subway']).sort_values(ascending=False)
resu_pi
# Out:
# totalSecondCnt    0.341895
# Subway            0.335265
# Tallgate          0.322840
# dtype: float64

# %%
sns.barplot(x=resu_pi, y=resu_pi.index)
plt.show()
